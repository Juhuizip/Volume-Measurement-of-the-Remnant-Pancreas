# %%
pwd
# Out:
# '/home/gil/gcubme_ai2/Workspace/JH_Lee/juhui_pancreas/head_op/isotropic_voxel_recon/05_DL_model/03_residual/CV1'

# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   
os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %%
import numpy as np
import matplotlib.pyplot as plt
import glob, os
import tensorflow as tf
import keras
from keras.models import Model
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, EarlyStopping,ReduceLROnPlateau
from keras import backend as K
#from keras.utils import multi_gpu_model
from tqdm import tqdm
from keras.layers import *
from keras.layers.normalization import BatchNormalization
# Out:
# /home/gil/anaconda3/envs/jjj/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/gil/anaconda3/envs/jjj/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/gil/anaconda3/envs/jjj/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/gil/anaconda3/envs/jjj/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/gil/anaconda3/envs/jjj/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/gil/anaconda3/envs/jjj/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/gil/anaconda3/envs/jjj/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/gil/anaconda3/envs/jjj/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/gil/anaconda3/envs/jjj/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/gil/anaconda3/envs/jjj/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/gil/anaconda3/envs/jjj/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/gil/anaconda3/envs/jjj/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.

# %%
IMG_DEPTH = 128
IMG_HEIGHT = 128
IMG_WIDTH = 128
IMG_CHANNELS = 1

# %%
def load_data3D(img_dir, msk_dir, IMG_DEPTH, IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS):

   
    img_list = sorted(glob.glob(img_dir +'/*.npy'))
    msk_list = sorted(glob.glob(msk_dir +'/*.npy'))
    
        
    X = np.ndarray((0, IMG_DEPTH, IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.float32)
    for dcm_no in tqdm(img_list):
        dcm_npy = np.load(dcm_no)    # shape = (IMG_DEPTH, IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS) 
        dcm_npy = np.expand_dims(dcm_npy, axis=0)
        X = np.concatenate((X, dcm_npy), axis=0)
        
    
    Y = np.ndarray((0, IMG_DEPTH, IMG_HEIGHT, IMG_WIDTH, 2), dtype=np.float32)
    for nii_no in tqdm(msk_list):
        nii_npy = np.load(nii_no)   # shape = (IMG_DEPTH, IMG_HEIGHT, IMG_WIDTH, 2) 
        nii_npy = np.expand_dims(nii_npy, axis=0)
        Y = np.concatenate((Y, nii_npy), axis=0)

    
    return X, Y

# %%
train_img_path = './train_img'
train_msk_path = './train_msk'
train_img, train_msk = load_data3D(train_img_path, train_msk_path, IMG_DEPTH, IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS)
np.save('./train_img.npy', train_img)
np.save('./train_msk.npy', train_msk)
print(f'train_img.dtype: {train_img.dtype} | train_img.shape: {train_img.shape}')
print(f'train_msk.dtype: {train_msk.dtype} | train_msk.shape: {train_msk.shape}')


print('='*50)


valid_img_path = './valid_img'
valid_msk_path = './valid_msk'
valid_img, valid_msk = load_data3D(valid_img_path, valid_msk_path, IMG_DEPTH, IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS)
np.save('./valid_img.npy', valid_img)
np.save('./valid_msk.npy', valid_msk)
print(f'valid_img.dtype: {valid_img.dtype} | valid_img.shape: {valid_img.shape}')
print(f'valid_msk.dtype: {valid_msk.dtype} | valid_msk.shape: {valid_msk.shape}')


print('='*50)


test_img_path = './test_img'
test_msk_path = './test_msk'
test_img, test_msk = load_data3D(test_img_path, test_msk_path, IMG_DEPTH, IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS)
np.save('./test_img.npy', test_img)
np.save('./test_msk.npy', test_msk)
print(f'test_img.dtype: {test_img.dtype} | test_img.shape: {test_img.shape}')
print(f'test_msk.dtype: {test_msk.dtype} | test_msk.shape: {test_msk.shape}')
# Out:
# 100%|██████████| 630/630 [08:16<00:00,  1.27it/s]
# 100%|██████████| 630/630 [13:53<00:00,  1.32s/it]
# train_img.dtype: float32 | train_img.shape: (630, 128, 128, 128, 1)
# train_msk.dtype: float32 | train_msk.shape: (630, 128, 128, 128, 2)
# ==================================================
# 100%|██████████| 209/209 [01:50<00:00,  1.89it/s]
# 100%|██████████| 209/209 [09:33<00:00,  2.75s/it]
# valid_img.dtype: float32 | valid_img.shape: (209, 128, 128, 128, 1)
# valid_msk.dtype: float32 | valid_msk.shape: (209, 128, 128, 128, 2)
# ==================================================
# 100%|██████████| 209/209 [01:30<00:00,  2.31it/s]
# 100%|██████████| 209/209 [05:17<00:00,  1.52s/it]
# test_img.dtype: float32 | test_img.shape: (209, 128, 128, 128, 1)
# test_msk.dtype: float32 | test_msk.shape: (209, 128, 128, 128, 2)

# %%
train_img = np.load('./train_img.npy')
train_msk = np.load('./train_msk.npy')
valid_img = np.load('./valid_img.npy')
valid_msk = np.load('./valid_msk.npy')
test_img = np.load('./test_img.npy')
test_msk = np.load('./test_msk.npy')


train_img = train_img / 255.0
valid_img = valid_img / 255.0
test_img = test_img / 255.0


train_msk = train_msk[:,:,:,:,1]
valid_msk = valid_msk[:,:,:,:,1]
test_msk = test_msk[:,:,:,:,1]


train_msk = np.expand_dims(train_msk, axis=4)
valid_msk = np.expand_dims(valid_msk, axis=4)
test_msk = np.expand_dims(test_msk, axis=4)


print(train_img.shape, np.max(train_img), np.min(train_img), train_img.dtype)
print(train_msk.shape, np.max(train_msk), np.min(train_msk), train_msk.dtype)
print(valid_img.shape, np.max(valid_img), np.min(valid_img), valid_img.dtype)
print(valid_msk.shape, np.max(valid_msk), np.min(valid_msk), valid_msk.dtype)
print(test_img.shape, np.max(test_img), np.min(test_img), test_img.dtype)
print(test_msk.shape, np.max(test_msk), np.min(test_msk), test_msk.dtype)
# Out:
# (630, 128, 128, 128, 1) 1.0 0.0 float32
# (630, 128, 128, 128, 1) 1.0 0.0 float32
# (209, 128, 128, 128, 1) 1.0 0.0 float32
# (209, 128, 128, 128, 1) 1.0 0.0 float32
# (209, 128, 128, 128, 1) 1.0 0.0 float32
# (209, 128, 128, 128, 1) 1.0 0.0 float32

# %%
import random
no = random.randrange(0,train_img.shape[0])
print(f'no: {no}')

plt.figure(figsize=(24,3))


plt.subplot(1,3,1)
plt_sample_img = train_img[no, 64, :,:,:]
plt.title("train_img")
plt.imshow(plt_sample_img, cmap = 'gray')


plt.subplot(1,3,2)
plt_sample_msk = train_msk[no, 64, :,:,:]
plt.title("train_msk[1]")
plt.imshow(plt_sample_msk, cmap = 'gray')


plt.subplot(1,3,3)
plt_sample_img = train_img[no, 64, :,:,:]
plt_sample_msk = train_msk[no, 64, :,:,:]
plt.title("train_msk[1] on train_img")
plt.imshow(plt_sample_img, cmap = 'gray')
plt.imshow(plt_sample_msk, cmap = 'Reds', alpha = 0.3)
# Out:
# no: 177

# %%
def res_block(input_layer, out_n_filters, batch_normalization=True, kernel_size=[3, 3, 3], stride=[1, 1, 1], 
              padding='same', data_format='channels_last'):
    
    if data_format == 'channels_first':
        input_n_filters = input_layer.get_shape().as_list()[1]
    else:
        input_n_filters = input_layer.get_shape().as_list()[4]

    layer = input_layer
    for i in range(2):
        layer = Conv3D(out_n_filters // 4, [1, 1, 1], strides=stride, padding=padding, data_format=data_format)(layer)
        if batch_normalization:
            layer = BatchNormalization()(layer)
        layer = Activation('relu')(layer)
        layer = Conv3D(out_n_filters // 4, kernel_size, strides=stride, padding=padding, data_format=data_format)(layer)
        layer = Conv3D(out_n_filters, [1, 1, 1], strides=stride, padding=padding, data_format=data_format)(layer)

    if out_n_filters != input_n_filters:
        skip_layer = Conv3D(out_n_filters, [1, 1, 1], strides=stride, padding=padding, data_format=data_format)(input_layer)
    else:
        skip_layer = input_layer
    out_layer = add([layer, skip_layer])
    return out_layer

def up_and_concate(down_layer, layer, data_format='channels_last'):
    
    if data_format == 'channels_first':
        in_channel = down_layer.get_shape().as_list()[1]
    else:
        in_channel = down_layer.get_shape().as_list()[4]

    # up = Conv2DTranspose(out_channel, [2, 2], strides=[2, 2])(down_layer)
    up = UpSampling3D(size=(2, 2, 2), data_format=data_format)(down_layer)

    if data_format == 'channels_first':
        my_concat = Lambda(lambda x: K.concatenate([x[0], x[1]], axis=1))
    else:
        my_concat = Lambda(lambda x: K.concatenate([x[0], x[1]], axis=4))

    concate = my_concat([up, layer])

    return concate

def residual_unet(input_img, n_label, data_format='channels_last'):
    inputs = input_img
    x = inputs
    depth = 4
    features = 32
    skips = []
    for i in range(depth):
        x = res_block(x, features, data_format=data_format)
        skips.append(x)
        x = MaxPooling3D((2, 2, 2), data_format=data_format)(x)

        features = features * 2

    x = res_block(x, features, data_format=data_format)

    for i in reversed(range(depth)):
        features = features // 2
        x = up_and_concate(x, skips[i], data_format=data_format)
        x = res_block(x, features, data_format=data_format)

    conv6 = Conv3D(n_label, (1, 1, 1), padding='same', data_format=data_format)(x)
    conv7 = core.Activation('sigmoid')(conv6)
    model = Model(inputs=inputs, outputs=conv7)
    #model.compile(optimizer=Adam(lr=1e-6), loss=[dice_coef_loss], metrics=['accuracy', dice_coef])
    return model

# %%
input_img = Input(shape=(IMG_DEPTH, IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
model = residual_unet(input_img = input_img, n_label=1)
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 128, 128, 128 0
# __________________________________________________________________________________________________
# conv3d_1 (Conv3D)               (None, 128, 128, 128 16          input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 128, 128, 128 32          conv3d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 128, 128, 128 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv3d_2 (Conv3D)               (None, 128, 128, 128 1736        activation_1[0][0]
# __________________________________________________________________________________________________
# conv3d_3 (Conv3D)               (None, 128, 128, 128 288         conv3d_2[0][0]
# __________________________________________________________________________________________________
# conv3d_4 (Conv3D)               (None, 128, 128, 128 264         conv3d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 128, 128, 128 32          conv3d_4[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 128, 128, 128 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv3d_5 (Conv3D)               (None, 128, 128, 128 1736        activation_2[0][0]
# __________________________________________________________________________________________________
# conv3d_6 (Conv3D)               (None, 128, 128, 128 288         conv3d_5[0][0]
# __________________________________________________________________________________________________
# conv3d_7 (Conv3D)               (None, 128, 128, 128 64          input_1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 128, 128, 128 0           conv3d_6[0][0]
#                                                                  conv3d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_1 (MaxPooling3D)  (None, 64, 64, 64, 3 0           add_1[0][0]
# __________________________________________________________________________________________________
# conv3d_8 (Conv3D)               (None, 64, 64, 64, 1 528         max_pooling3d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 64, 64, 64, 1 64          conv3d_8[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 64, 64, 64, 1 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv3d_9 (Conv3D)               (None, 64, 64, 64, 1 6928        activation_3[0][0]
# __________________________________________________________________________________________________
# conv3d_10 (Conv3D)              (None, 64, 64, 64, 6 1088        conv3d_9[0][0]
# __________________________________________________________________________________________________
# conv3d_11 (Conv3D)              (None, 64, 64, 64, 1 1040        conv3d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 64, 64, 64, 1 64          conv3d_11[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 64, 64, 64, 1 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv3d_12 (Conv3D)              (None, 64, 64, 64, 1 6928        activation_4[0][0]
# __________________________________________________________________________________________________
# conv3d_13 (Conv3D)              (None, 64, 64, 64, 6 1088        conv3d_12[0][0]
# __________________________________________________________________________________________________
# conv3d_14 (Conv3D)              (None, 64, 64, 64, 6 2112        max_pooling3d_1[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 64, 64, 64, 6 0           conv3d_13[0][0]
#                                                                  conv3d_14[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_2 (MaxPooling3D)  (None, 32, 32, 32, 6 0           add_2[0][0]
# __________________________________________________________________________________________________
# conv3d_15 (Conv3D)              (None, 32, 32, 32, 3 2080        max_pooling3d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 32, 32, 3 128         conv3d_15[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 32, 32, 32, 3 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv3d_16 (Conv3D)              (None, 32, 32, 32, 3 27680       activation_5[0][0]
# __________________________________________________________________________________________________
# conv3d_17 (Conv3D)              (None, 32, 32, 32, 1 4224        conv3d_16[0][0]
# __________________________________________________________________________________________________
# conv3d_18 (Conv3D)              (None, 32, 32, 32, 3 4128        conv3d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 32, 32, 32, 3 128         conv3d_18[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 32, 32, 32, 3 0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv3d_19 (Conv3D)              (None, 32, 32, 32, 3 27680       activation_6[0][0]
# __________________________________________________________________________________________________
# conv3d_20 (Conv3D)              (None, 32, 32, 32, 1 4224        conv3d_19[0][0]
# __________________________________________________________________________________________________
# conv3d_21 (Conv3D)              (None, 32, 32, 32, 1 8320        max_pooling3d_2[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 32, 32, 32, 1 0           conv3d_20[0][0]
#                                                                  conv3d_21[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_3 (MaxPooling3D)  (None, 16, 16, 16, 1 0           add_3[0][0]
# __________________________________________________________________________________________________
# conv3d_22 (Conv3D)              (None, 16, 16, 16, 6 8256        max_pooling3d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 16, 16, 16, 6 256         conv3d_22[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 16, 16, 16, 6 0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv3d_23 (Conv3D)              (None, 16, 16, 16, 6 110656      activation_7[0][0]
# __________________________________________________________________________________________________
# conv3d_24 (Conv3D)              (None, 16, 16, 16, 2 16640       conv3d_23[0][0]
# __________________________________________________________________________________________________
# conv3d_25 (Conv3D)              (None, 16, 16, 16, 6 16448       conv3d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 16, 16, 16, 6 256         conv3d_25[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 16, 16, 16, 6 0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv3d_26 (Conv3D)              (None, 16, 16, 16, 6 110656      activation_8[0][0]
# __________________________________________________________________________________________________
# conv3d_27 (Conv3D)              (None, 16, 16, 16, 2 16640       conv3d_26[0][0]
# __________________________________________________________________________________________________
# conv3d_28 (Conv3D)              (None, 16, 16, 16, 2 33024       max_pooling3d_3[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 16, 16, 16, 2 0           conv3d_27[0][0]
#                                                                  conv3d_28[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_4 (MaxPooling3D)  (None, 8, 8, 8, 256) 0           add_4[0][0]
# __________________________________________________________________________________________________
# conv3d_29 (Conv3D)              (None, 8, 8, 8, 128) 32896       max_pooling3d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 8, 8, 8, 128) 512         conv3d_29[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 8, 8, 8, 128) 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv3d_30 (Conv3D)              (None, 8, 8, 8, 128) 442496      activation_9[0][0]
# __________________________________________________________________________________________________
# conv3d_31 (Conv3D)              (None, 8, 8, 8, 512) 66048       conv3d_30[0][0]
# __________________________________________________________________________________________________
# conv3d_32 (Conv3D)              (None, 8, 8, 8, 128) 65664       conv3d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 8, 8, 8, 128) 512         conv3d_32[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 8, 8, 8, 128) 0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv3d_33 (Conv3D)              (None, 8, 8, 8, 128) 442496      activation_10[0][0]
# __________________________________________________________________________________________________
# conv3d_34 (Conv3D)              (None, 8, 8, 8, 512) 66048       conv3d_33[0][0]
# __________________________________________________________________________________________________
# conv3d_35 (Conv3D)              (None, 8, 8, 8, 512) 131584      max_pooling3d_4[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 8, 8, 8, 512) 0           conv3d_34[0][0]
#                                                                  conv3d_35[0][0]
# __________________________________________________________________________________________________
# up_sampling3d_1 (UpSampling3D)  (None, 16, 16, 16, 5 0           add_5[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 16, 16, 16, 7 0           up_sampling3d_1[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# conv3d_36 (Conv3D)              (None, 16, 16, 16, 6 49216       lambda_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 16, 16, 16, 6 256         conv3d_36[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 16, 16, 16, 6 0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv3d_37 (Conv3D)              (None, 16, 16, 16, 6 110656      activation_11[0][0]
# __________________________________________________________________________________________________
# conv3d_38 (Conv3D)              (None, 16, 16, 16, 2 16640       conv3d_37[0][0]
# __________________________________________________________________________________________________
# conv3d_39 (Conv3D)              (None, 16, 16, 16, 6 16448       conv3d_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 16, 16, 16, 6 256         conv3d_39[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 16, 16, 16, 6 0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv3d_40 (Conv3D)              (None, 16, 16, 16, 6 110656      activation_12[0][0]
# __________________________________________________________________________________________________
# conv3d_41 (Conv3D)              (None, 16, 16, 16, 2 16640       conv3d_40[0][0]
# __________________________________________________________________________________________________
# conv3d_42 (Conv3D)              (None, 16, 16, 16, 2 196864      lambda_1[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 16, 16, 16, 2 0           conv3d_41[0][0]
#                                                                  conv3d_42[0][0]
# __________________________________________________________________________________________________
# up_sampling3d_2 (UpSampling3D)  (None, 32, 32, 32, 2 0           add_6[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 32, 32, 32, 3 0           up_sampling3d_2[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# conv3d_43 (Conv3D)              (None, 32, 32, 32, 3 12320       lambda_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 32, 32, 32, 3 128         conv3d_43[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 32, 32, 32, 3 0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv3d_44 (Conv3D)              (None, 32, 32, 32, 3 27680       activation_13[0][0]
# __________________________________________________________________________________________________
# conv3d_45 (Conv3D)              (None, 32, 32, 32, 1 4224        conv3d_44[0][0]
# __________________________________________________________________________________________________
# conv3d_46 (Conv3D)              (None, 32, 32, 32, 3 4128        conv3d_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 32, 32, 32, 3 128         conv3d_46[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 32, 32, 32, 3 0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv3d_47 (Conv3D)              (None, 32, 32, 32, 3 27680       activation_14[0][0]
# __________________________________________________________________________________________________
# conv3d_48 (Conv3D)              (None, 32, 32, 32, 1 4224        conv3d_47[0][0]
# __________________________________________________________________________________________________
# conv3d_49 (Conv3D)              (None, 32, 32, 32, 1 49280       lambda_2[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 32, 32, 32, 1 0           conv3d_48[0][0]
#                                                                  conv3d_49[0][0]
# __________________________________________________________________________________________________
# up_sampling3d_3 (UpSampling3D)  (None, 64, 64, 64, 1 0           add_7[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 64, 64, 64, 1 0           up_sampling3d_3[0][0]
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# conv3d_50 (Conv3D)              (None, 64, 64, 64, 1 3088        lambda_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 64, 64, 64, 1 64          conv3d_50[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 64, 64, 64, 1 0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv3d_51 (Conv3D)              (None, 64, 64, 64, 1 6928        activation_15[0][0]
# __________________________________________________________________________________________________
# conv3d_52 (Conv3D)              (None, 64, 64, 64, 6 1088        conv3d_51[0][0]
# __________________________________________________________________________________________________
# conv3d_53 (Conv3D)              (None, 64, 64, 64, 1 1040        conv3d_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 64, 64, 64, 1 64          conv3d_53[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 64, 64, 64, 1 0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv3d_54 (Conv3D)              (None, 64, 64, 64, 1 6928        activation_16[0][0]
# __________________________________________________________________________________________________
# conv3d_55 (Conv3D)              (None, 64, 64, 64, 6 1088        conv3d_54[0][0]
# __________________________________________________________________________________________________
# conv3d_56 (Conv3D)              (None, 64, 64, 64, 6 12352       lambda_3[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 64, 64, 64, 6 0           conv3d_55[0][0]
#                                                                  conv3d_56[0][0]
# __________________________________________________________________________________________________
# up_sampling3d_4 (UpSampling3D)  (None, 128, 128, 128 0           add_8[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 128, 128, 128 0           up_sampling3d_4[0][0]
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# conv3d_57 (Conv3D)              (None, 128, 128, 128 776         lambda_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 128, 128, 128 32          conv3d_57[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 128, 128, 128 0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv3d_58 (Conv3D)              (None, 128, 128, 128 1736        activation_17[0][0]
# __________________________________________________________________________________________________
# conv3d_59 (Conv3D)              (None, 128, 128, 128 288         conv3d_58[0][0]
# __________________________________________________________________________________________________
# conv3d_60 (Conv3D)              (None, 128, 128, 128 264         conv3d_59[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 128, 128, 128 32          conv3d_60[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 128, 128, 128 0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv3d_61 (Conv3D)              (None, 128, 128, 128 1736        activation_18[0][0]
# __________________________________________________________________________________________________
# conv3d_62 (Conv3D)              (None, 128, 128, 128 288         conv3d_61[0][0]
# __________________________________________________________________________________________________
# conv3d_63 (Conv3D)              (None, 128, 128, 128 3104        lambda_4[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 128, 128, 128 0           conv3d_62[0][0]
#                                                                  conv3d_63[0][0]
# __________________________________________________________________________________________________
# conv3d_64 (Conv3D)              (None, 128, 128, 128 33          add_9[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 128, 128, 128 0           conv3d_64[0][0]
# ==================================================================================================
# Total params: 2,352,329
# Trainable params: 2,350,857
# Non-trainable params: 1,472
# __________________________________________________________________________________________________

# %%
def dice_cost_0(y_true, y_predicted):

    mask_true = y_true[:, :, :, :, 0]
    mask_pred = y_predicted[:, :, :, :, 0]

    num_sum = 2.0 * K.sum(mask_true * mask_pred) + K.epsilon()
    den_sum = K.sum(mask_true) + K.sum(mask_pred)+ K.epsilon()

    return num_sum/den_sum



def dice_cost_1(y_true, y_predicted):

    mask_true = y_true[:, :, :, :, 1]
    mask_pred = y_predicted[:, :, :, :, 1]

    num_sum = 2.0 * K.sum(mask_true * mask_pred) + K.epsilon()
    den_sum = K.sum(mask_true) + K.sum(mask_pred)+ K.epsilon()

    return num_sum/den_sum


def dice_cost_1_loss(y_true, y_predicted):

    mask_true = y_true[:, :, :, :, 1]
    mask_pred = y_predicted[:, :, :, :, 1]

    num_sum = 2.0 * K.sum(mask_true * mask_pred) + K.epsilon()
    den_sum = K.sum(mask_true) + K.sum(mask_pred)+ K.epsilon()
    
    return 1-(num_sum/den_sum)


def dice_cost_01(y_true, y_predicted):

    dice_1 = dice_cost_0(y_true, y_predicted)
    dice_2 = dice_cost_1(y_true, y_predicted)


    return 1/2*(dice_1+dice_2)

def dice_coef(y_true, y_pred, smooth=1):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def dice_coef_loss(y_true, y_pred):
    return 1-dice_coef(y_true, y_pred)


# Ref: salehi17, "Twersky loss function for image segmentation using 3D FCDN"
# -> the score is computed for each class separately and then summed
# alpha=beta=0.5 : dice coefficient
# alpha=beta=1   : tanimoto coefficient (also known as jaccard)
# alpha+beta=1   : produces set of F*-scores
# implemented by E. Moebel, 06/04/18
def tversky_loss(y_true, y_pred):
    alpha = 0.5
    beta  = 0.5
    
    ones = K.ones(K.shape(y_true))
    p0 = y_pred      # proba that voxels are class i
    p1 = ones-y_pred # proba that voxels are not class i
    g0 = y_true
    g1 = ones-y_true
    
    num = K.sum(p0*g0, (0,1,2,3))
    den = num + alpha*K.sum(p0*g1,(0,1,2,3)) + beta*K.sum(p1*g0,(0,1,2,3))
    
    T = K.sum(num/den) # when summing over classes, T has dynamic range [0 Ncl]
    
    Ncl = K.cast(K.shape(y_true)[-1], 'float32')
    return Ncl-T

# %%
monitor = 'val_loss'

#model = multi_gpu_model(model, gpus=8)
model.compile(optimizer=Adam(lr=0.0001), loss=tversky_loss, metrics=[dice_cost_0])

checkpointer = ModelCheckpoint(filepath='./3D_residual_Unet_CV1.h5', verbose=1, save_best_only=True)
reduce_lr = ReduceLROnPlateau(monitor=monitor, factor=0.1,
                              patience=10, min_lr=0.000001,verbose=1)
earlystopper = EarlyStopping(monitor=monitor, patience=35, verbose=1)

# %%
callbacks = [reduce_lr, earlystopper, checkpointer]

results = model.fit(train_img, train_msk, 
                    validation_data=(valid_img, valid_msk), 
                    epochs=500, 
                    verbose=1,
                    batch_size=2, 
                    callbacks=callbacks)
# Out:
# WARNING:tensorflow:From /home/gil/anaconda3/envs/jjj/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 630 samples, validate on 209 samples
# Epoch 1/500
# 630/630 [==============================] - 269s 427ms/step - loss: 0.4341 - dice_cost_0: 0.5659 - val_loss: 0.9315 - val_dice_cost_0: 0.0682
#
# Epoch 00001: val_loss improved from inf to 0.93152, saving model to ./3D_residual_Unet_CV1.h5
# Epoch 2/500
# 630/630 [==============================] - 155s 246ms/step - loss: 0.3140 - dice_cost_0: 0.6860 - val_loss: 0.3583 - val_dice_cost_0: 0.6412
#
# Epoch 00002: val_loss improved from 0.93152 to 0.35829, saving model to ./3D_residual_Unet_CV1.h5
# Epoch 3/500
# 630/630 [==============================] - 155s 246ms/step - loss: 0.2724 - dice_cost_0: 0.7276 - val_loss: 0.2908 - val_dice_cost_0: 0.7087
#
# Epoch 00003: val_loss improved from 0.35829 to 0.29079, saving model to ./3D_residual_Unet_CV1.h5
# Epoch 4/500
# 630/630 [==============================] - 155s 246ms/step - loss: 0.2465 - dice_cost_0: 0.7535 - val_loss: 0.3027 - val_dice_cost_0: 0.6970
#
# Epoch 00004: val_loss did not improve from 0.29079
# Epoch 5/500
# 630/630 [==============================] - 155s 246ms/step - loss: 0.2319 - dice_cost_0: 0.7681 - val_loss: 0.2966 - val_dice_cost_0: 0.7030
#
# Epoch 00005: val_loss did not improve from 0.29079
# Epoch 6/500
# 630/630 [==============================] - 156s 248ms/step - loss: 0.2214 - dice_cost_0: 0.7786 - val_loss: 0.3179 - val_dice_cost_0: 0.6819
#
# Epoch 00006: val_loss did not improve from 0.29079
# Epoch 7/500
# 630/630 [==============================] - 156s 247ms/step - loss: 0.2042 - dice_cost_0: 0.7958 - val_loss: 0.2754 - val_dice_cost_0: 0.7242
#
# Epoch 00007: val_loss improved from 0.29079 to 0.27541, saving model to ./3D_residual_Unet_CV1.h5
# Epoch 8/500
# 630/630 [==============================] - 157s 249ms/step - loss: 0.1960 - dice_cost_0: 0.8040 - val_loss: 0.3192 - val_dice_cost_0: 0.6804
#
# Epoch 00008: val_loss did not improve from 0.27541
# Epoch 9/500
# 630/630 [==============================] - 156s 248ms/step - loss: 0.1925 - dice_cost_0: 0.8075 - val_loss: 0.3526 - val_dice_cost_0: 0.6470
#
# Epoch 00009: val_loss did not improve from 0.27541
# Epoch 10/500
# 630/630 [==============================] - 156s 248ms/step - loss: 0.1842 - dice_cost_0: 0.8158 - val_loss: 0.2861 - val_dice_cost_0: 0.7135
#
# Epoch 00010: val_loss did not improve from 0.27541
# Epoch 11/500
# 630/630 [==============================] - 155s 247ms/step - loss: 0.1755 - dice_cost_0: 0.8245 - val_loss: 0.2779 - val_dice_cost_0: 0.7219
#
# Epoch 00011: val_loss did not improve from 0.27541
# Epoch 12/500
# 630/630 [==============================] - 155s 246ms/step - loss: 0.1708 - dice_cost_0: 0.8292 - val_loss: 0.3398 - val_dice_cost_0: 0.6596
#
# Epoch 00012: val_loss did not improve from 0.27541
# Epoch 13/500
# 630/630 [==============================] - 156s 248ms/step - loss: 0.1765 - dice_cost_0: 0.8235 - val_loss: 0.2937 - val_dice_cost_0: 0.7058
#
# Epoch 00013: val_loss did not improve from 0.27541
# Epoch 14/500
# 630/630 [==============================] - 157s 250ms/step - loss: 0.1650 - dice_cost_0: 0.8350 - val_loss: 0.2661 - val_dice_cost_0: 0.7334
#
# Epoch 00014: val_loss improved from 0.27541 to 0.26614, saving model to ./3D_residual_Unet_CV1.h5
# Epoch 15/500
# 630/630 [==============================] - 160s 254ms/step - loss: 0.1570 - dice_cost_0: 0.8430 - val_loss: 0.2787 - val_dice_cost_0: 0.7211
#
# Epoch 00015: val_loss did not improve from 0.26614
# Epoch 16/500
# 630/630 [==============================] - 157s 250ms/step - loss: 0.1570 - dice_cost_0: 0.8430 - val_loss: 0.2738 - val_dice_cost_0: 0.7256
#
# Epoch 00016: val_loss did not improve from 0.26614
# Epoch 17/500
# 630/630 [==============================] - 156s 247ms/step - loss: 0.1532 - dice_cost_0: 0.8468 - val_loss: 0.2993 - val_dice_cost_0: 0.7004
#
# Epoch 00017: val_loss did not improve from 0.26614
# Epoch 18/500
# 630/630 [==============================] - 155s 247ms/step - loss: 0.1494 - dice_cost_0: 0.8506 - val_loss: 0.2911 - val_dice_cost_0: 0.7084
#
# Epoch 00018: val_loss did not improve from 0.26614
# Epoch 19/500
# 630/630 [==============================] - 157s 249ms/step - loss: 0.1465 - dice_cost_0: 0.8535 - val_loss: 0.2709 - val_dice_cost_0: 0.7287
#
# Epoch 00019: val_loss did not improve from 0.26614
# Epoch 20/500
# 630/630 [==============================] - 157s 249ms/step - loss: 0.1496 - dice_cost_0: 0.8504 - val_loss: 0.2619 - val_dice_cost_0: 0.7376
#
# Epoch 00020: val_loss improved from 0.26614 to 0.26192, saving model to ./3D_residual_Unet_CV1.h5
# Epoch 21/500
# 630/630 [==============================] - 156s 247ms/step - loss: 0.1409 - dice_cost_0: 0.8591 - val_loss: 0.2634 - val_dice_cost_0: 0.7362
#
# Epoch 00021: val_loss did not improve from 0.26192
# Epoch 22/500
# 630/630 [==============================] - 156s 247ms/step - loss: 0.1356 - dice_cost_0: 0.8644 - val_loss: 0.2679 - val_dice_cost_0: 0.7318
#
# Epoch 00022: val_loss did not improve from 0.26192
# Epoch 23/500
# 630/630 [==============================] - 155s 247ms/step - loss: 0.1340 - dice_cost_0: 0.8660 - val_loss: 0.2727 - val_dice_cost_0: 0.7269
#
# Epoch 00023: val_loss did not improve from 0.26192
# Epoch 24/500
# 630/630 [==============================] - 156s 247ms/step - loss: 0.1319 - dice_cost_0: 0.8681 - val_loss: 0.2687 - val_dice_cost_0: 0.7311
#
# Epoch 00024: val_loss did not improve from 0.26192
# Epoch 25/500
# 630/630 [==============================] - 156s 247ms/step - loss: 0.1297 - dice_cost_0: 0.8703 - val_loss: 0.2982 - val_dice_cost_0: 0.7017
#
# Epoch 00025: val_loss did not improve from 0.26192
# Epoch 26/500
# 630/630 [==============================] - 156s 248ms/step - loss: 0.1301 - dice_cost_0: 0.8699 - val_loss: 0.2802 - val_dice_cost_0: 0.7192
#
# Epoch 00026: val_loss did not improve from 0.26192
# Epoch 27/500
# 630/630 [==============================] - 156s 247ms/step - loss: 0.1273 - dice_cost_0: 0.8727 - val_loss: 0.2654 - val_dice_cost_0: 0.7339
#
# Epoch 00027: val_loss did not improve from 0.26192
# Epoch 28/500
# 630/630 [==============================] - 155s 246ms/step - loss: 0.1243 - dice_cost_0: 0.8757 - val_loss: 0.2682 - val_dice_cost_0: 0.7312
#
# Epoch 00028: val_loss did not improve from 0.26192
# Epoch 29/500
# 630/630 [==============================] - 156s 247ms/step - loss: 0.1202 - dice_cost_0: 0.8798 - val_loss: 0.2668 - val_dice_cost_0: 0.7328
#
# Epoch 00029: val_loss did not improve from 0.26192
# Epoch 30/500
# 630/630 [==============================] - 156s 247ms/step - loss: 0.1194 - dice_cost_0: 0.8806 - val_loss: 0.2783 - val_dice_cost_0: 0.7210
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
#
# Epoch 00030: val_loss did not improve from 0.26192
# Epoch 31/500
# 630/630 [==============================] - 156s 247ms/step - loss: 0.1118 - dice_cost_0: 0.8882 - val_loss: 0.2608 - val_dice_cost_0: 0.7387
#
# Epoch 00031: val_loss improved from 0.26192 to 0.26082, saving model to ./3D_residual_Unet_CV1.h5
# Epoch 32/500
# 630/630 [==============================] - 156s 248ms/step - loss: 0.1069 - dice_cost_0: 0.8931 - val_loss: 0.2635 - val_dice_cost_0: 0.7360
#
# Epoch 00032: val_loss did not improve from 0.26082
# Epoch 33/500
# 630/630 [==============================] - 156s 247ms/step - loss: 0.1041 - dice_cost_0: 0.8959 - val_loss: 0.2650 - val_dice_cost_0: 0.7344
#
# Epoch 00033: val_loss did not improve from 0.26082
# Epoch 34/500
# 630/630 [==============================] - 156s 247ms/step - loss: 0.1027 - dice_cost_0: 0.8973 - val_loss: 0.2635 - val_dice_cost_0: 0.7359
#
# Epoch 00034: val_loss did not improve from 0.26082
# Epoch 35/500
# 630/630 [==============================] - 156s 248ms/step - loss: 0.1003 - dice_cost_0: 0.8997 - val_loss: 0.2660 - val_dice_cost_0: 0.7335
#
# Epoch 00035: val_loss did not improve from 0.26082
# Epoch 36/500
# 630/630 [==============================] - 156s 248ms/step - loss: 0.0989 - dice_cost_0: 0.9011 - val_loss: 0.2641 - val_dice_cost_0: 0.7354
#
# Epoch 00036: val_loss did not improve from 0.26082
# Epoch 37/500
# 630/630 [==============================] - 156s 247ms/step - loss: 0.0979 - dice_cost_0: 0.9021 - val_loss: 0.2635 - val_dice_cost_0: 0.7360
#
# Epoch 00037: val_loss did not improve from 0.26082
# Epoch 38/500
# 630/630 [==============================] - 156s 247ms/step - loss: 0.0966 - dice_cost_0: 0.9034 - val_loss: 0.2675 - val_dice_cost_0: 0.7320
#
# Epoch 00038: val_loss did not improve from 0.26082
# Epoch 39/500
# 630/630 [==============================] - 155s 246ms/step - loss: 0.0957 - dice_cost_0: 0.9043 - val_loss: 0.2649 - val_dice_cost_0: 0.7346
#
# Epoch 00039: val_loss did not improve from 0.26082
# Epoch 40/500
# 630/630 [==============================] - 156s 247ms/step - loss: 0.0949 - dice_cost_0: 0.9051 - val_loss: 0.2660 - val_dice_cost_0: 0.7335
#
# Epoch 00040: val_loss did not improve from 0.26082
# Epoch 41/500
# 630/630 [==============================] - 155s 245ms/step - loss: 0.0938 - dice_cost_0: 0.9062 - val_loss: 0.2664 - val_dice_cost_0: 0.7330
#
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 1e-06.
#
# Epoch 00041: val_loss did not improve from 0.26082
# Epoch 42/500
# 630/630 [==============================] - 156s 247ms/step - loss: 0.0926 - dice_cost_0: 0.9074 - val_loss: 0.2653 - val_dice_cost_0: 0.7341
#
# Epoch 00042: val_loss did not improve from 0.26082
# Epoch 43/500
# 630/630 [==============================] - 155s 246ms/step - loss: 0.0925 - dice_cost_0: 0.9075 - val_loss: 0.2661 - val_dice_cost_0: 0.7333
#
# Epoch 00043: val_loss did not improve from 0.26082
# Epoch 44/500
# 630/630 [==============================] - 156s 247ms/step - loss: 0.0923 - dice_cost_0: 0.9077 - val_loss: 0.2666 - val_dice_cost_0: 0.7328
#
# Epoch 00044: val_loss did not improve from 0.26082
# Epoch 45/500
# 630/630 [==============================] - 155s 247ms/step - loss: 0.0921 - dice_cost_0: 0.9079 - val_loss: 0.2660 - val_dice_cost_0: 0.7334
#
# Epoch 00045: val_loss did not improve from 0.26082
# Epoch 46/500
# 630/630 [==============================] - 155s 246ms/step - loss: 0.0921 - dice_cost_0: 0.9079 - val_loss: 0.2661 - val_dice_cost_0: 0.7333
#
# Epoch 00046: val_loss did not improve from 0.26082
# Epoch 47/500
# 630/630 [==============================] - 155s 246ms/step - loss: 0.0916 - dice_cost_0: 0.9084 - val_loss: 0.2662 - val_dice_cost_0: 0.7332
#
# Epoch 00047: val_loss did not improve from 0.26082
# Epoch 48/500
# 630/630 [==============================] - 156s 247ms/step - loss: 0.0917 - dice_cost_0: 0.9083 - val_loss: 0.2664 - val_dice_cost_0: 0.7330
#
# Epoch 00048: val_loss did not improve from 0.26082
# Epoch 49/500
# 630/630 [==============================] - 155s 247ms/step - loss: 0.0915 - dice_cost_0: 0.9085 - val_loss: 0.2665 - val_dice_cost_0: 0.7329
#
# Epoch 00049: val_loss did not improve from 0.26082
# Epoch 50/500
# 630/630 [==============================] - 155s 247ms/step - loss: 0.0914 - dice_cost_0: 0.9086 - val_loss: 0.2662 - val_dice_cost_0: 0.7332
#
# Epoch 00050: val_loss did not improve from 0.26082
# Epoch 51/500
# 630/630 [==============================] - 156s 247ms/step - loss: 0.0911 - dice_cost_0: 0.9089 - val_loss: 0.2665 - val_dice_cost_0: 0.7329
#
# Epoch 00051: val_loss did not improve from 0.26082
# Epoch 52/500
# 630/630 [==============================] - 156s 247ms/step - loss: 0.0909 - dice_cost_0: 0.9091 - val_loss: 0.2663 - val_dice_cost_0: 0.7331
#
# Epoch 00052: val_loss did not improve from 0.26082
# Epoch 53/500
# 630/630 [==============================] - 155s 246ms/step - loss: 0.0910 - dice_cost_0: 0.9090 - val_loss: 0.2666 - val_dice_cost_0: 0.7328
#
# Epoch 00053: val_loss did not improve from 0.26082
# Epoch 54/500
# 630/630 [==============================] - 155s 247ms/step - loss: 0.0911 - dice_cost_0: 0.9089 - val_loss: 0.2666 - val_dice_cost_0: 0.7328
#
# Epoch 00054: val_loss did not improve from 0.26082
# Epoch 55/500
# 630/630 [==============================] - 156s 247ms/step - loss: 0.0907 - dice_cost_0: 0.9093 - val_loss: 0.2669 - val_dice_cost_0: 0.7325
#
# Epoch 00055: val_loss did not improve from 0.26082
# Epoch 56/500
# 630/630 [==============================] - 156s 247ms/step - loss: 0.0906 - dice_cost_0: 0.9094 - val_loss: 0.2668 - val_dice_cost_0: 0.7326
#
# Epoch 00056: val_loss did not improve from 0.26082
# Epoch 57/500
# 630/630 [==============================] - 155s 247ms/step - loss: 0.0905 - dice_cost_0: 0.9095 - val_loss: 0.2672 - val_dice_cost_0: 0.7323
#
# Epoch 00057: val_loss did not improve from 0.26082
# Epoch 58/500
# 630/630 [==============================] - 155s 246ms/step - loss: 0.0905 - dice_cost_0: 0.9095 - val_loss: 0.2672 - val_dice_cost_0: 0.7323
#
# Epoch 00058: val_loss did not improve from 0.26082
# Epoch 59/500
# 630/630 [==============================] - 155s 246ms/step - loss: 0.0901 - dice_cost_0: 0.9099 - val_loss: 0.2668 - val_dice_cost_0: 0.7326
#
# Epoch 00059: val_loss did not improve from 0.26082
# Epoch 60/500
# 630/630 [==============================] - 155s 246ms/step - loss: 0.0906 - dice_cost_0: 0.9094 - val_loss: 0.2666 - val_dice_cost_0: 0.7329
#
# Epoch 00060: val_loss did not improve from 0.26082
# Epoch 61/500
# 630/630 [==============================] - 155s 246ms/step - loss: 0.0902 - dice_cost_0: 0.9098 - val_loss: 0.2668 - val_dice_cost_0: 0.7326
#
# Epoch 00061: val_loss did not improve from 0.26082
# Epoch 62/500
# 630/630 [==============================] - 155s 246ms/step - loss: 0.0899 - dice_cost_0: 0.9101 - val_loss: 0.2666 - val_dice_cost_0: 0.7328
#
# Epoch 00062: val_loss did not improve from 0.26082
# Epoch 63/500
# 630/630 [==============================] - 154s 245ms/step - loss: 0.0903 - dice_cost_0: 0.9097 - val_loss: 0.2668 - val_dice_cost_0: 0.7326
#
# Epoch 00063: val_loss did not improve from 0.26082
# Epoch 64/500
# 630/630 [==============================] - 155s 246ms/step - loss: 0.0900 - dice_cost_0: 0.9100 - val_loss: 0.2670 - val_dice_cost_0: 0.7324
#
# Epoch 00064: val_loss did not improve from 0.26082
# Epoch 65/500
# 630/630 [==============================] - 156s 247ms/step - loss: 0.0899 - dice_cost_0: 0.9101 - val_loss: 0.2670 - val_dice_cost_0: 0.7324
#
# Epoch 00065: val_loss did not improve from 0.26082
# Epoch 66/500
# 630/630 [==============================] - 155s 246ms/step - loss: 0.0899 - dice_cost_0: 0.9101 - val_loss: 0.2671 - val_dice_cost_0: 0.7323
#
# Epoch 00066: val_loss did not improve from 0.26082
# Epoch 00066: early stopping

# %%
fig = plt.figure()
# plt.axes(facecolor='white')
plt.plot(results.history['loss'])
plt.plot(results.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.savefig('loss.png')

# %%
from keras.models import load_model

#test_model = load_model('./3D_basic_Unet_CV1.h5',
#                   custom_objects = {'tversky_loss': tversky_loss,
#                                     'dice_cost_0': dice_cost_0,
#                                     'dice_cost_1': dice_cost_1,
#                                     'dice_cost_1_loss': dice_cost_1_loss})


test_model = load_model('./3D_residual_Unet_CV1.h5',
                   custom_objects = {'tversky_loss': tversky_loss,
                                     'dice_cost_0': dice_cost_0})

test_model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 128, 128, 128 0
# __________________________________________________________________________________________________
# conv3d_1 (Conv3D)               (None, 128, 128, 128 16          input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 128, 128, 128 32          conv3d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 128, 128, 128 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv3d_2 (Conv3D)               (None, 128, 128, 128 1736        activation_1[0][0]
# __________________________________________________________________________________________________
# conv3d_3 (Conv3D)               (None, 128, 128, 128 288         conv3d_2[0][0]
# __________________________________________________________________________________________________
# conv3d_4 (Conv3D)               (None, 128, 128, 128 264         conv3d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 128, 128, 128 32          conv3d_4[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 128, 128, 128 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv3d_5 (Conv3D)               (None, 128, 128, 128 1736        activation_2[0][0]
# __________________________________________________________________________________________________
# conv3d_6 (Conv3D)               (None, 128, 128, 128 288         conv3d_5[0][0]
# __________________________________________________________________________________________________
# conv3d_7 (Conv3D)               (None, 128, 128, 128 64          input_1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 128, 128, 128 0           conv3d_6[0][0]
#                                                                  conv3d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_1 (MaxPooling3D)  (None, 64, 64, 64, 3 0           add_1[0][0]
# __________________________________________________________________________________________________
# conv3d_8 (Conv3D)               (None, 64, 64, 64, 1 528         max_pooling3d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 64, 64, 64, 1 64          conv3d_8[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 64, 64, 64, 1 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv3d_9 (Conv3D)               (None, 64, 64, 64, 1 6928        activation_3[0][0]
# __________________________________________________________________________________________________
# conv3d_10 (Conv3D)              (None, 64, 64, 64, 6 1088        conv3d_9[0][0]
# __________________________________________________________________________________________________
# conv3d_11 (Conv3D)              (None, 64, 64, 64, 1 1040        conv3d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 64, 64, 64, 1 64          conv3d_11[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 64, 64, 64, 1 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv3d_12 (Conv3D)              (None, 64, 64, 64, 1 6928        activation_4[0][0]
# __________________________________________________________________________________________________
# conv3d_13 (Conv3D)              (None, 64, 64, 64, 6 1088        conv3d_12[0][0]
# __________________________________________________________________________________________________
# conv3d_14 (Conv3D)              (None, 64, 64, 64, 6 2112        max_pooling3d_1[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 64, 64, 64, 6 0           conv3d_13[0][0]
#                                                                  conv3d_14[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_2 (MaxPooling3D)  (None, 32, 32, 32, 6 0           add_2[0][0]
# __________________________________________________________________________________________________
# conv3d_15 (Conv3D)              (None, 32, 32, 32, 3 2080        max_pooling3d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 32, 32, 3 128         conv3d_15[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 32, 32, 32, 3 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv3d_16 (Conv3D)              (None, 32, 32, 32, 3 27680       activation_5[0][0]
# __________________________________________________________________________________________________
# conv3d_17 (Conv3D)              (None, 32, 32, 32, 1 4224        conv3d_16[0][0]
# __________________________________________________________________________________________________
# conv3d_18 (Conv3D)              (None, 32, 32, 32, 3 4128        conv3d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 32, 32, 32, 3 128         conv3d_18[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 32, 32, 32, 3 0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv3d_19 (Conv3D)              (None, 32, 32, 32, 3 27680       activation_6[0][0]
# __________________________________________________________________________________________________
# conv3d_20 (Conv3D)              (None, 32, 32, 32, 1 4224        conv3d_19[0][0]
# __________________________________________________________________________________________________
# conv3d_21 (Conv3D)              (None, 32, 32, 32, 1 8320        max_pooling3d_2[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 32, 32, 32, 1 0           conv3d_20[0][0]
#                                                                  conv3d_21[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_3 (MaxPooling3D)  (None, 16, 16, 16, 1 0           add_3[0][0]
# __________________________________________________________________________________________________
# conv3d_22 (Conv3D)              (None, 16, 16, 16, 6 8256        max_pooling3d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 16, 16, 16, 6 256         conv3d_22[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 16, 16, 16, 6 0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv3d_23 (Conv3D)              (None, 16, 16, 16, 6 110656      activation_7[0][0]
# __________________________________________________________________________________________________
# conv3d_24 (Conv3D)              (None, 16, 16, 16, 2 16640       conv3d_23[0][0]
# __________________________________________________________________________________________________
# conv3d_25 (Conv3D)              (None, 16, 16, 16, 6 16448       conv3d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 16, 16, 16, 6 256         conv3d_25[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 16, 16, 16, 6 0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv3d_26 (Conv3D)              (None, 16, 16, 16, 6 110656      activation_8[0][0]
# __________________________________________________________________________________________________
# conv3d_27 (Conv3D)              (None, 16, 16, 16, 2 16640       conv3d_26[0][0]
# __________________________________________________________________________________________________
# conv3d_28 (Conv3D)              (None, 16, 16, 16, 2 33024       max_pooling3d_3[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 16, 16, 16, 2 0           conv3d_27[0][0]
#                                                                  conv3d_28[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_4 (MaxPooling3D)  (None, 8, 8, 8, 256) 0           add_4[0][0]
# __________________________________________________________________________________________________
# conv3d_29 (Conv3D)              (None, 8, 8, 8, 128) 32896       max_pooling3d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 8, 8, 8, 128) 512         conv3d_29[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 8, 8, 8, 128) 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv3d_30 (Conv3D)              (None, 8, 8, 8, 128) 442496      activation_9[0][0]
# __________________________________________________________________________________________________
# conv3d_31 (Conv3D)              (None, 8, 8, 8, 512) 66048       conv3d_30[0][0]
# __________________________________________________________________________________________________
# conv3d_32 (Conv3D)              (None, 8, 8, 8, 128) 65664       conv3d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 8, 8, 8, 128) 512         conv3d_32[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 8, 8, 8, 128) 0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv3d_33 (Conv3D)              (None, 8, 8, 8, 128) 442496      activation_10[0][0]
# __________________________________________________________________________________________________
# conv3d_34 (Conv3D)              (None, 8, 8, 8, 512) 66048       conv3d_33[0][0]
# __________________________________________________________________________________________________
# conv3d_35 (Conv3D)              (None, 8, 8, 8, 512) 131584      max_pooling3d_4[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 8, 8, 8, 512) 0           conv3d_34[0][0]
#                                                                  conv3d_35[0][0]
# __________________________________________________________________________________________________
# up_sampling3d_1 (UpSampling3D)  (None, 16, 16, 16, 5 0           add_5[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 16, 16, 16, 7 0           up_sampling3d_1[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# conv3d_36 (Conv3D)              (None, 16, 16, 16, 6 49216       lambda_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 16, 16, 16, 6 256         conv3d_36[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 16, 16, 16, 6 0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv3d_37 (Conv3D)              (None, 16, 16, 16, 6 110656      activation_11[0][0]
# __________________________________________________________________________________________________
# conv3d_38 (Conv3D)              (None, 16, 16, 16, 2 16640       conv3d_37[0][0]
# __________________________________________________________________________________________________
# conv3d_39 (Conv3D)              (None, 16, 16, 16, 6 16448       conv3d_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 16, 16, 16, 6 256         conv3d_39[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 16, 16, 16, 6 0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv3d_40 (Conv3D)              (None, 16, 16, 16, 6 110656      activation_12[0][0]
# __________________________________________________________________________________________________
# conv3d_41 (Conv3D)              (None, 16, 16, 16, 2 16640       conv3d_40[0][0]
# __________________________________________________________________________________________________
# conv3d_42 (Conv3D)              (None, 16, 16, 16, 2 196864      lambda_1[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 16, 16, 16, 2 0           conv3d_41[0][0]
#                                                                  conv3d_42[0][0]
# __________________________________________________________________________________________________
# up_sampling3d_2 (UpSampling3D)  (None, 32, 32, 32, 2 0           add_6[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 32, 32, 32, 3 0           up_sampling3d_2[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# conv3d_43 (Conv3D)              (None, 32, 32, 32, 3 12320       lambda_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 32, 32, 32, 3 128         conv3d_43[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 32, 32, 32, 3 0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv3d_44 (Conv3D)              (None, 32, 32, 32, 3 27680       activation_13[0][0]
# __________________________________________________________________________________________________
# conv3d_45 (Conv3D)              (None, 32, 32, 32, 1 4224        conv3d_44[0][0]
# __________________________________________________________________________________________________
# conv3d_46 (Conv3D)              (None, 32, 32, 32, 3 4128        conv3d_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 32, 32, 32, 3 128         conv3d_46[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 32, 32, 32, 3 0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv3d_47 (Conv3D)              (None, 32, 32, 32, 3 27680       activation_14[0][0]
# __________________________________________________________________________________________________
# conv3d_48 (Conv3D)              (None, 32, 32, 32, 1 4224        conv3d_47[0][0]
# __________________________________________________________________________________________________
# conv3d_49 (Conv3D)              (None, 32, 32, 32, 1 49280       lambda_2[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 32, 32, 32, 1 0           conv3d_48[0][0]
#                                                                  conv3d_49[0][0]
# __________________________________________________________________________________________________
# up_sampling3d_3 (UpSampling3D)  (None, 64, 64, 64, 1 0           add_7[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 64, 64, 64, 1 0           up_sampling3d_3[0][0]
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# conv3d_50 (Conv3D)              (None, 64, 64, 64, 1 3088        lambda_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 64, 64, 64, 1 64          conv3d_50[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 64, 64, 64, 1 0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv3d_51 (Conv3D)              (None, 64, 64, 64, 1 6928        activation_15[0][0]
# __________________________________________________________________________________________________
# conv3d_52 (Conv3D)              (None, 64, 64, 64, 6 1088        conv3d_51[0][0]
# __________________________________________________________________________________________________
# conv3d_53 (Conv3D)              (None, 64, 64, 64, 1 1040        conv3d_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 64, 64, 64, 1 64          conv3d_53[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 64, 64, 64, 1 0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv3d_54 (Conv3D)              (None, 64, 64, 64, 1 6928        activation_16[0][0]
# __________________________________________________________________________________________________
# conv3d_55 (Conv3D)              (None, 64, 64, 64, 6 1088        conv3d_54[0][0]
# __________________________________________________________________________________________________
# conv3d_56 (Conv3D)              (None, 64, 64, 64, 6 12352       lambda_3[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 64, 64, 64, 6 0           conv3d_55[0][0]
#                                                                  conv3d_56[0][0]
# __________________________________________________________________________________________________
# up_sampling3d_4 (UpSampling3D)  (None, 128, 128, 128 0           add_8[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 128, 128, 128 0           up_sampling3d_4[0][0]
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# conv3d_57 (Conv3D)              (None, 128, 128, 128 776         lambda_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 128, 128, 128 32          conv3d_57[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 128, 128, 128 0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv3d_58 (Conv3D)              (None, 128, 128, 128 1736        activation_17[0][0]
# __________________________________________________________________________________________________
# conv3d_59 (Conv3D)              (None, 128, 128, 128 288         conv3d_58[0][0]
# __________________________________________________________________________________________________
# conv3d_60 (Conv3D)              (None, 128, 128, 128 264         conv3d_59[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 128, 128, 128 32          conv3d_60[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 128, 128, 128 0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv3d_61 (Conv3D)              (None, 128, 128, 128 1736        activation_18[0][0]
# __________________________________________________________________________________________________
# conv3d_62 (Conv3D)              (None, 128, 128, 128 288         conv3d_61[0][0]
# __________________________________________________________________________________________________
# conv3d_63 (Conv3D)              (None, 128, 128, 128 3104        lambda_4[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 128, 128, 128 0           conv3d_62[0][0]
#                                                                  conv3d_63[0][0]
# __________________________________________________________________________________________________
# conv3d_64 (Conv3D)              (None, 128, 128, 128 33          add_9[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 128, 128, 128 0           conv3d_64[0][0]
# ==================================================================================================
# Total params: 2,352,329
# Trainable params: 2,350,857
# Non-trainable params: 1,472
# __________________________________________________________________________________________________

# %%
test_img = np.load('./test_img.npy')
test_msk = np.load('./test_msk.npy')


test_img = test_img / 255.0

test_msk = test_msk[:,:,:,:,1]
test_msk = np.expand_dims(test_msk, axis=4)


print(test_img.shape, np.max(test_img), np.min(test_img), test_img.dtype)
print(test_msk.shape, np.max(test_msk), np.min(test_msk), test_msk.dtype)
# Out:
# (209, 128, 128, 128, 1) 1.0 0.0 float32
# (209, 128, 128, 128, 1) 1.0 0.0 float32

# %%
test_pred = model.predict(test_img, batch_size=2, verbose=1)

np.save('./pred_result_CV1.npy', test_pred)

print(test_pred.shape, np.max(test_pred), np.min(test_pred), test_pred.dtype)
# Out:
# 209/209 [==============================] - 15s 69ms/step
# (209, 128, 128, 128, 1) 1.0 0.0 float32

# %%
# 평가지표 구하는 수식
recall_list = []
specificity_list = []
precision_list = []
acc_list = []
dice_list = []

for i in range(test_msk.shape[0]):
    for j in range(test_msk.shape[1]):
        
        seg1 = test_pred[i,j,:,:,0] > 0.5
        gt1 = test_msk[i,j,:,:,0]
        
        #if np.sum(gt1) != 0:
            
        seg1_n = seg1 == 0
        seg1_t = seg1 == 1
        
        gt1_n = gt1 == 0
        gt1_t = gt1 == 1
        
        tp = np.sum(seg1_t&gt1_t)
        
        fp = np.sum(seg1_t&gt1_n)
        
        tn = np.sum(seg1_n&gt1_n)
        
        fn = np.sum(seg1_n&gt1_t)
        
       
        recall = tp / (tp + fn)
        if np.isnan(recall):
            #print('recall is nan {0}\t(tp:{1})\t tn:{2}\t fp:{3}\t(fn:{4})'.format(i, tp, tn, fp, fn))
            continue
        
        specificity = tn / (tn + fp)
        if np.isnan(specificity):
            #print('specificity is nan {0}\t tp:{1}\t(tn:{2})\t(fp:{3})\t fn:{4}'.format(i, tp, tn, fp, fn))
            continue
        
        precision = tp / (tp + fp)
        if np.isnan(precision):
            #print('precision is nan {0}\t(tp:{1})\t tn:{2}\t(fp:{3})\t fn:{4}'.format(i, tp, tn, fp, fn))
            continue
        
        acc = (tp + tn) / (tp + tn + fp + fn)
        if np.isnan(acc):
            #print('acc is nan {0}\t(tp:{1})\t(tn:{2})\t(fp:{3})\t(fn:{4})'.format(i, tp, tn, fp, fn))
            continue
            
        dice = (2 * tp) / ((2 * tp) + fp + fn)
        if np.isnan(dice):
            #print('dice is nan {0}\t(tp:{1})\t tn:{2}\t(fp:{3})\t(fn:{4})'.format(i, tp, tn, fp, fn))
            continue
        
        #print('='*50)
        recall_list.append(recall)
        specificity_list.append(specificity)
        precision_list.append(precision)
        acc_list.append(acc)
        dice_list.append(dice)
# Out:
# /home/gil/anaconda3/envs/jjj/lib/python3.6/site-packages/ipykernel_launcher.py:31: RuntimeWarning: invalid value encountered in long_scalars
# /home/gil/anaconda3/envs/jjj/lib/python3.6/site-packages/ipykernel_launcher.py:41: RuntimeWarning: invalid value encountered in long_scalars

# %%
from tabulate import tabulate
row_data1 = []
row_item1 = []

    
row_item1.append('{0:.4f}'.format(np.mean(recall_list)))
row_item1.append('{0:.4f}'.format(np.mean(specificity_list)))
row_item1.append('{0:.4f}'.format(np.mean(precision_list)))
row_item1.append('{0:.4f}'.format(np.mean(acc_list)))
row_item1.append('{0:.4f}'.format(np.mean(dice_list)))
row_data1.append(row_item1)

head1 = ["Sensitivity", "Specificity", "Precision", "Accuracy", "DSC"]
  
# display table
print(tabulate(row_data1, headers=head1, tablefmt="grid"))
#print(row_data1[n])
print('')
# Out:
# +---------------+---------------+-------------+------------+--------+
# |   Sensitivity |   Specificity |   Precision |   Accuracy |    DSC |
# +===============+===============+=============+============+========+
# |        0.6992 |        0.9899 |      0.7719 |      0.977 | 0.6962 |
# +---------------+---------------+-------------+------------+--------+

# %%
for i in range(0, test_img.shape[0]):
    
    os.makedirs('./result_img/' + str(format(i, '03')), exist_ok=True)
    for j in range(0, test_img.shape[1]):
        
        
        fig, axs = plt.subplots(1,3,constrained_layout=True)
        
        #plt.figure(figsize=(10, 20))
    
        axs[0].imshow(test_img[i,j,:,:,0], cmap='gray')
        axs[0].axis('off')
        

        axs[1].imshow(test_msk[i,j,:,:,0], cmap='gray')
        axs[1].axis('off')
    

        axs[2].imshow(test_img[i,j,:,:,0], cmap='gray')
        axs[2].imshow(test_pred[i,j,:,:,0] > 0.3, cmap='Reds', alpha=0.7)
        axs[2].axis('off')
    
        #plt.show()
        fig.savefig('./result_img/' + str(format(i, '03')) + '/'+ str(format(j, '03')) + '.png')
