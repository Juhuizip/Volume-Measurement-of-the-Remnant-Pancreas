# %%
pwd
# Out:
# '/home/gil/gcubme_ai2/Workspace/JH_Lee/juhui_pancreas/head_op/isotropic_voxel_recon/05_DL_model/02_dense/CV1'

# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   
os.environ["CUDA_VISIBLE_DEVICES"]="1"

# %%
import numpy as np
import matplotlib.pyplot as plt
import glob, os
import tensorflow as tf
import keras
from keras.models import Model
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, EarlyStopping,ReduceLROnPlateau
from keras import backend as K
#from keras.utils import multi_gpu_model
from tqdm import tqdm
from keras.layers import *
from keras.layers.normalization import BatchNormalization

# %%
IMG_DEPTH = 128
IMG_HEIGHT = 128
IMG_WIDTH = 128
IMG_CHANNELS = 1

# %%
def load_data3D(img_dir, msk_dir, IMG_DEPTH, IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS):

   
    img_list = sorted(glob.glob(img_dir +'/*.npy'))
    msk_list = sorted(glob.glob(msk_dir +'/*.npy'))
    
        
    X = np.ndarray((0, IMG_DEPTH, IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.float32)
    for dcm_no in tqdm(img_list):
        dcm_npy = np.load(dcm_no)    # shape = (IMG_DEPTH, IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS) 
        dcm_npy = np.expand_dims(dcm_npy, axis=0)
        X = np.concatenate((X, dcm_npy), axis=0)
        
    
    Y = np.ndarray((0, IMG_DEPTH, IMG_HEIGHT, IMG_WIDTH, 2), dtype=np.float32)
    for nii_no in tqdm(msk_list):
        nii_npy = np.load(nii_no)   # shape = (IMG_DEPTH, IMG_HEIGHT, IMG_WIDTH, 2) 
        nii_npy = np.expand_dims(nii_npy, axis=0)
        Y = np.concatenate((Y, nii_npy), axis=0)

    
    return X, Y

# %%
train_img_path = './train_img'
train_msk_path = './train_msk'
train_img, train_msk = load_data3D(train_img_path, train_msk_path, IMG_DEPTH, IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS)
np.save('./train_img.npy', train_img)
np.save('./train_msk.npy', train_msk)
print(f'train_img.dtype: {train_img.dtype} | train_img.shape: {train_img.shape}')
print(f'train_msk.dtype: {train_msk.dtype} | train_msk.shape: {train_msk.shape}')


print('='*50)


valid_img_path = './valid_img'
valid_msk_path = './valid_msk'
valid_img, valid_msk = load_data3D(valid_img_path, valid_msk_path, IMG_DEPTH, IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS)
np.save('./valid_img.npy', valid_img)
np.save('./valid_msk.npy', valid_msk)
print(f'valid_img.dtype: {valid_img.dtype} | valid_img.shape: {valid_img.shape}')
print(f'valid_msk.dtype: {valid_msk.dtype} | valid_msk.shape: {valid_msk.shape}')


print('='*50)


test_img_path = './test_img'
test_msk_path = './test_msk'
test_img, test_msk = load_data3D(test_img_path, test_msk_path, IMG_DEPTH, IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS)
np.save('./test_img.npy', test_img)
np.save('./test_msk.npy', test_msk)
print(f'test_img.dtype: {test_img.dtype} | test_img.shape: {test_img.shape}')
print(f'test_msk.dtype: {test_msk.dtype} | test_msk.shape: {test_msk.shape}')
# Out:
# 100%|██████████| 630/630 [06:20<00:00,  1.66it/s]
# 100%|██████████| 630/630 [13:23<00:00,  1.28s/it]
# train_img.dtype: float32 | train_img.shape: (630, 128, 128, 128, 1)
# train_msk.dtype: float32 | train_msk.shape: (630, 128, 128, 128, 2)
# ==================================================
# 100%|██████████| 209/209 [05:53<00:00,  1.69s/it]
# 100%|██████████| 209/209 [05:23<00:00,  1.55s/it]
# valid_img.dtype: float32 | valid_img.shape: (209, 128, 128, 128, 1)
# valid_msk.dtype: float32 | valid_msk.shape: (209, 128, 128, 128, 2)
# ==================================================
# 100%|██████████| 209/209 [02:47<00:00,  1.24it/s]
# 100%|██████████| 209/209 [04:10<00:00,  1.20s/it]
# test_img.dtype: float32 | test_img.shape: (209, 128, 128, 128, 1)
# test_msk.dtype: float32 | test_msk.shape: (209, 128, 128, 128, 2)

# %%
train_img = np.load('./train_img.npy')
train_msk = np.load('./train_msk.npy')
valid_img = np.load('./valid_img.npy')
valid_msk = np.load('./valid_msk.npy')
test_img = np.load('./test_img.npy')
test_msk = np.load('./test_msk.npy')


train_img = train_img / 255.0
valid_img = valid_img / 255.0
test_img = test_img / 255.0


train_msk = train_msk[:,:,:,:,1]
valid_msk = valid_msk[:,:,:,:,1]
test_msk = test_msk[:,:,:,:,1]


train_msk = np.expand_dims(train_msk, axis=4)
valid_msk = np.expand_dims(valid_msk, axis=4)
test_msk = np.expand_dims(test_msk, axis=4)


print(train_img.shape, np.max(train_img), np.min(train_img), train_img.dtype)
print(train_msk.shape, np.max(train_msk), np.min(train_msk), train_msk.dtype)
print(valid_img.shape, np.max(valid_img), np.min(valid_img), valid_img.dtype)
print(valid_msk.shape, np.max(valid_msk), np.min(valid_msk), valid_msk.dtype)
print(test_img.shape, np.max(test_img), np.min(test_img), test_img.dtype)
print(test_msk.shape, np.max(test_msk), np.min(test_msk), test_msk.dtype)
# Out:
# (630, 128, 128, 128, 1) 1.0 0.0 float32
# (630, 128, 128, 128, 1) 1.0 0.0 float32
# (209, 128, 128, 128, 1) 1.0 0.0 float32
# (209, 128, 128, 128, 1) 1.0 0.0 float32
# (209, 128, 128, 128, 1) 1.0 0.0 float32
# (209, 128, 128, 128, 1) 1.0 0.0 float32

# %%
import random
no = random.randrange(0,train_img.shape[0])
print(f'no: {no}')

plt.figure(figsize=(24,3))


plt.subplot(1,3,1)
plt_sample_img = train_img[no, 64, :,:,:]
plt.title("train_img")
plt.imshow(plt_sample_img, cmap = 'gray')


plt.subplot(1,3,2)
plt_sample_msk = train_msk[no, 64, :,:,:]
plt.title("train_msk[1]")
plt.imshow(plt_sample_msk, cmap = 'gray')


plt.subplot(1,3,3)
plt_sample_img = train_img[no, 64, :,:,:]
plt_sample_msk = train_msk[no, 64, :,:,:]
plt.title("train_msk[1] on train_img")
plt.imshow(plt_sample_img, cmap = 'gray')
plt.imshow(plt_sample_msk, cmap = 'Reds', alpha = 0.3)
# Out:
# no: 501

# %%
def upsample_conv(filters, kernel_size, strides, padding):
    return Conv3DTranspose(filters, kernel_size, strides=strides, padding=padding)


def upsample_simple(filters, kernel_size, strides, padding):
    return UpSampling3D(strides)

def Dense_U_Net(input_img, mode = 'tran', base = 32, scale = 2, num_classes = 7):
    if mode == 'tran':
        upsample = upsample_conv
    elif mode == 'simp':
        upsample = upsample_simple
    conv1_1 = Conv3D(base, 3, activation=None, padding='same', kernel_initializer='he_normal')(input_img)
    conv1_1 = BatchNormalization()(conv1_1)
    conv1_1 = Activation(activation='relu')(conv1_1)
    conv1_2 = Conv3D(base, 3, activation=None, padding='same', kernel_initializer='he_normal')(conv1_1)
    conv1_2 = BatchNormalization()(conv1_2)
    conv1_2 = Activation(activation='relu')(conv1_2)
    
    conv1 = concatenate([conv1_1, conv1_2], axis = 4)
    pool1 = MaxPooling3D(pool_size=(2, 2, 2))(conv1)

    conv2_1 = Conv3D((scale) * base, 3, activation=None, padding='same', kernel_initializer='he_normal')(pool1)
    conv2_1 = BatchNormalization()(conv2_1)
    conv2_1 = Activation(activation='relu')(conv2_1)
    conv2_2 = Conv3D((scale) * base, 3, activation=None, padding='same', kernel_initializer='he_normal')(conv2_1)
    conv2_2 = BatchNormalization()(conv2_2)
    conv2_2 = Activation(activation='relu')(conv2_2)
    
    conv2 = concatenate([conv2_1, conv2_2], axis = 4)
    pool2 = MaxPooling3D(pool_size=(2, 2, 2))(conv2)

    conv3_1 = Conv3D((scale * scale) * base, 3, activation=None, padding='same', kernel_initializer='he_normal')(pool2)
    conv3_1 = BatchNormalization()(conv3_1)
    conv3_1 = Activation(activation='relu')(conv3_1)
    conv3_2 = Conv3D((scale * scale) * base, 3, activation=None, padding='same', kernel_initializer='he_normal')(conv3_1)
    conv3_2 = BatchNormalization()(conv3_2)
    conv3_2 = Activation(activation='relu')(conv3_2)
    
    conv3 = concatenate([conv3_1, conv3_2], axis = 4)
    pool3 = MaxPooling3D(pool_size=(2, 2, 2))(conv3)

    conv4_1 = Conv3D((scale * scale * scale) * base, 3, activation=None, padding='same', kernel_initializer='he_normal')(pool3)
    conv4_1 = BatchNormalization()(conv4_1)
    conv4_1 = Activation(activation='relu')(conv4_1)
    conv4_2 = Conv3D((scale * scale * scale) * base, 3, activation=None, padding='same', kernel_initializer='he_normal')(conv4_1)
    conv4_2 = BatchNormalization()(conv4_2)
    conv4_2 = Activation(activation='relu')(conv4_2)
    
    conv4 = concatenate([conv4_1, conv4_2], axis = 4)
    pool4 = MaxPooling3D(pool_size=(2, 2, 2))(conv4)

    conv5_1 = Conv3D((scale * scale * scale * scale) * base, 3, activation=None, padding='same', kernel_initializer='he_normal')(pool4)
    conv5_1 = BatchNormalization()(conv5_1)
    conv5_1 = Activation(activation='relu')(conv5_1)
    conv5_2 = Conv3D((scale * scale * scale * scale) * base, 3, activation=None, padding='same', kernel_initializer='he_normal')(conv5_1)
    conv5_2 = BatchNormalization()(conv5_2)
    conv5_2 = Activation(activation='relu')(conv5_2)
    conv5 = concatenate([conv5_1, conv5_2], axis = 4)
    
    
    pool6 = upsample((scale * scale * scale) * base, (2, 2, 2), strides=(2, 2, 2), padding='same')(conv5)
    merge = concatenate([conv4, pool6], axis = 4)
    conv6_1 = Conv3D((scale * scale * scale) * base, 3, activation=None, padding='same', kernel_initializer='he_normal')(merge)
    conv6_1 = BatchNormalization()(conv6_1)
    conv6_1 = Activation(activation='relu')(conv6_1)
    conv6_2 = Conv3D((scale * scale * scale) * base, 3, activation=None, padding='same', kernel_initializer='he_normal')(conv6_1)
    conv6_2 = BatchNormalization()(conv6_2)
    conv6_2 = Activation(activation='relu')(conv6_2)
    conv6 = concatenate([conv6_1, conv6_2], axis = 4)

    pool7 = upsample((scale * scale) * base, (2, 2, 2), strides=(2, 2, 2), padding='same')(conv6)
    merge = concatenate([conv3, pool7], axis = 4)
    conv7_1 = Conv3D((scale * scale) * base, 3, activation=None, padding='same', kernel_initializer='he_normal')(merge)
    conv7_1 = BatchNormalization()(conv7_1)
    conv7_1 = Activation(activation='relu')(conv7_1)
    conv7_2 = Conv3D((scale * scale) * base, 3, activation=None, padding='same', kernel_initializer='he_normal')(conv7_1)
    conv7_2 = BatchNormalization()(conv7_2)
    conv7_2 = Activation(activation='relu')(conv7_2)
    conv7 = concatenate([conv7_1, conv7_2], axis = 4)

    pool8 = upsample(scale * base, (2, 2, 2), strides=(2, 2, 2), padding='same')(conv7)
    merge = concatenate([conv2, pool8], axis = 4)
    conv8_1 = Conv3D(scale * base, 3, activation=None, padding='same', kernel_initializer='he_normal')(merge)
    conv8_1 = BatchNormalization()(conv8_1)
    conv8_1 = Activation(activation='relu')(conv8_1)
    conv8_2 = Conv3D(scale * base, 3, activation=None, padding='same', kernel_initializer='he_normal')(conv8_1)
    conv8_2 = BatchNormalization()(conv8_2)
    conv8_2 = Activation(activation='relu')(conv8_2)
    conv8 = concatenate([conv8_1, conv8_2], axis = 4)

    pool9 = upsample(base, (2, 2, 2), strides=(2, 2, 2), padding='same')(conv8)
    merge = concatenate([conv1, pool9], axis = 4)
    conv9 = Conv3D(base, 3, activation='relu', padding='same', kernel_initializer='he_normal')(merge)
    
    out = Conv3D(num_classes, 3, activation='sigmoid', padding='same')(conv9)
    model = Model(inputs=input_img, outputs=out)
    
    return model

# %%
input_img = Input(shape=(IMG_DEPTH, IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
model = Dense_U_Net(input_img, mode = 'simp', base = 32, scale = 2, num_classes = 1)
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 128, 128, 128 0
# __________________________________________________________________________________________________
# conv3d_1 (Conv3D)               (None, 128, 128, 128 896         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 128, 128, 128 128         conv3d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 128, 128, 128 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv3d_2 (Conv3D)               (None, 128, 128, 128 27680       activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 128, 128, 128 128         conv3d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 128, 128, 128 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 128, 128, 128 0           activation_1[0][0]
#                                                                  activation_2[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_1 (MaxPooling3D)  (None, 64, 64, 64, 6 0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv3d_3 (Conv3D)               (None, 64, 64, 64, 6 110656      max_pooling3d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 64, 64, 64, 6 256         conv3d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 64, 64, 64, 6 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv3d_4 (Conv3D)               (None, 64, 64, 64, 6 110656      activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 64, 64, 64, 6 256         conv3d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 64, 64, 64, 6 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 64, 64, 64, 1 0           activation_3[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_2 (MaxPooling3D)  (None, 32, 32, 32, 1 0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv3d_5 (Conv3D)               (None, 32, 32, 32, 1 442496      max_pooling3d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 32, 32, 1 512         conv3d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 32, 32, 32, 1 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv3d_6 (Conv3D)               (None, 32, 32, 32, 1 442496      activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 32, 32, 32, 1 512         conv3d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 32, 32, 32, 1 0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 32, 32, 32, 2 0           activation_5[0][0]
#                                                                  activation_6[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_3 (MaxPooling3D)  (None, 16, 16, 16, 2 0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv3d_7 (Conv3D)               (None, 16, 16, 16, 2 1769728     max_pooling3d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 16, 16, 16, 2 1024        conv3d_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 16, 16, 16, 2 0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv3d_8 (Conv3D)               (None, 16, 16, 16, 2 1769728     activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 16, 16, 16, 2 1024        conv3d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 16, 16, 16, 2 0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 16, 16, 16, 5 0           activation_7[0][0]
#                                                                  activation_8[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_4 (MaxPooling3D)  (None, 8, 8, 8, 512) 0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv3d_9 (Conv3D)               (None, 8, 8, 8, 512) 7078400     max_pooling3d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 8, 8, 8, 512) 2048        conv3d_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 8, 8, 8, 512) 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv3d_10 (Conv3D)              (None, 8, 8, 8, 512) 7078400     activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 8, 8, 8, 512) 2048        conv3d_10[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 8, 8, 8, 512) 0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 8, 8, 8, 1024 0           activation_9[0][0]
#                                                                  activation_10[0][0]
# __________________________________________________________________________________________________
# up_sampling3d_1 (UpSampling3D)  (None, 16, 16, 16, 1 0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 16, 16, 16, 1 0           concatenate_4[0][0]
#                                                                  up_sampling3d_1[0][0]
# __________________________________________________________________________________________________
# conv3d_11 (Conv3D)              (None, 16, 16, 16, 2 10617088    concatenate_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 16, 16, 16, 2 1024        conv3d_11[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 16, 16, 16, 2 0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv3d_12 (Conv3D)              (None, 16, 16, 16, 2 1769728     activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 16, 16, 16, 2 1024        conv3d_12[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 16, 16, 16, 2 0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 16, 16, 16, 5 0           activation_11[0][0]
#                                                                  activation_12[0][0]
# __________________________________________________________________________________________________
# up_sampling3d_2 (UpSampling3D)  (None, 32, 32, 32, 5 0           concatenate_7[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 32, 32, 32, 7 0           concatenate_3[0][0]
#                                                                  up_sampling3d_2[0][0]
# __________________________________________________________________________________________________
# conv3d_13 (Conv3D)              (None, 32, 32, 32, 1 2654336     concatenate_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 32, 32, 32, 1 512         conv3d_13[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 32, 32, 32, 1 0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv3d_14 (Conv3D)              (None, 32, 32, 32, 1 442496      activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 32, 32, 32, 1 512         conv3d_14[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 32, 32, 32, 1 0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 32, 32, 32, 2 0           activation_13[0][0]
#                                                                  activation_14[0][0]
# __________________________________________________________________________________________________
# up_sampling3d_3 (UpSampling3D)  (None, 64, 64, 64, 2 0           concatenate_9[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 64, 64, 64, 3 0           concatenate_2[0][0]
#                                                                  up_sampling3d_3[0][0]
# __________________________________________________________________________________________________
# conv3d_15 (Conv3D)              (None, 64, 64, 64, 6 663616      concatenate_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 64, 64, 64, 6 256         conv3d_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 64, 64, 64, 6 0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv3d_16 (Conv3D)              (None, 64, 64, 64, 6 110656      activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 64, 64, 64, 6 256         conv3d_16[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 64, 64, 64, 6 0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 64, 64, 64, 1 0           activation_15[0][0]
#                                                                  activation_16[0][0]
# __________________________________________________________________________________________________
# up_sampling3d_4 (UpSampling3D)  (None, 128, 128, 128 0           concatenate_11[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 128, 128, 128 0           concatenate_1[0][0]
#                                                                  up_sampling3d_4[0][0]
# __________________________________________________________________________________________________
# conv3d_17 (Conv3D)              (None, 128, 128, 128 165920      concatenate_12[0][0]
# __________________________________________________________________________________________________
# conv3d_18 (Conv3D)              (None, 128, 128, 128 865         conv3d_17[0][0]
# ==================================================================================================
# Total params: 35,267,361
# Trainable params: 35,261,601
# Non-trainable params: 5,760
# __________________________________________________________________________________________________

# %%
def dice_cost_0(y_true, y_predicted):

    mask_true = y_true[:, :, :, :, 0]
    mask_pred = y_predicted[:, :, :, :, 0]

    num_sum = 2.0 * K.sum(mask_true * mask_pred) + K.epsilon()
    den_sum = K.sum(mask_true) + K.sum(mask_pred)+ K.epsilon()

    return num_sum/den_sum



def dice_cost_1(y_true, y_predicted):

    mask_true = y_true[:, :, :, :, 1]
    mask_pred = y_predicted[:, :, :, :, 1]

    num_sum = 2.0 * K.sum(mask_true * mask_pred) + K.epsilon()
    den_sum = K.sum(mask_true) + K.sum(mask_pred)+ K.epsilon()

    return num_sum/den_sum


def dice_cost_1_loss(y_true, y_predicted):

    mask_true = y_true[:, :, :, :, 1]
    mask_pred = y_predicted[:, :, :, :, 1]

    num_sum = 2.0 * K.sum(mask_true * mask_pred) + K.epsilon()
    den_sum = K.sum(mask_true) + K.sum(mask_pred)+ K.epsilon()
    
    return 1-(num_sum/den_sum)


def dice_cost_01(y_true, y_predicted):

    dice_1 = dice_cost_0(y_true, y_predicted)
    dice_2 = dice_cost_1(y_true, y_predicted)


    return 1/2*(dice_1+dice_2)

def dice_coef(y_true, y_pred, smooth=1):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def dice_coef_loss(y_true, y_pred):
    return 1-dice_coef(y_true, y_pred)


# Ref: salehi17, "Twersky loss function for image segmentation using 3D FCDN"
# -> the score is computed for each class separately and then summed
# alpha=beta=0.5 : dice coefficient
# alpha=beta=1   : tanimoto coefficient (also known as jaccard)
# alpha+beta=1   : produces set of F*-scores
# implemented by E. Moebel, 06/04/18
def tversky_loss(y_true, y_pred):
    alpha = 0.5
    beta  = 0.5
    
    ones = K.ones(K.shape(y_true))
    p0 = y_pred      # proba that voxels are class i
    p1 = ones-y_pred # proba that voxels are not class i
    g0 = y_true
    g1 = ones-y_true
    
    num = K.sum(p0*g0, (0,1,2,3))
    den = num + alpha*K.sum(p0*g1,(0,1,2,3)) + beta*K.sum(p1*g0,(0,1,2,3))
    
    T = K.sum(num/den) # when summing over classes, T has dynamic range [0 Ncl]
    
    Ncl = K.cast(K.shape(y_true)[-1], 'float32')
    return Ncl-T

# %%
monitor = 'val_loss'

#model = multi_gpu_model(model, gpus=8)
model.compile(optimizer=Adam(lr=0.0001), loss=tversky_loss, metrics=[dice_cost_0])

checkpointer = ModelCheckpoint(filepath='./3D_dense_Unet_CV1.h5', verbose=1, save_best_only=True)
reduce_lr = ReduceLROnPlateau(monitor=monitor, factor=0.1,
                              patience=10, min_lr=0.000001,verbose=1)
earlystopper = EarlyStopping(monitor=monitor, patience=35, verbose=1)

# %%
callbacks = [reduce_lr, earlystopper, checkpointer]

results = model.fit(train_img, train_msk, 
                    validation_data=(valid_img, valid_msk), 
                    epochs=500, 
                    verbose=1,
                    batch_size=2, 
                    callbacks=callbacks)
# Out:
# WARNING:tensorflow:From /home/gil/anaconda3/envs/jjj/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 630 samples, validate on 209 samples
# Epoch 1/500
# 630/630 [==============================] - 763s 1s/step - loss: 0.3596 - dice_cost_0: 0.6404 - val_loss: 0.3194 - val_dice_cost_0: 0.6798
#
# Epoch 00001: val_loss improved from inf to 0.31936, saving model to ./3D_dense_Unet_CV1.h5
# Epoch 2/500
# 630/630 [==============================] - 596s 946ms/step - loss: 0.2683 - dice_cost_0: 0.7317 - val_loss: 0.2909 - val_dice_cost_0: 0.7084
#
# Epoch 00002: val_loss improved from 0.31936 to 0.29093, saving model to ./3D_dense_Unet_CV1.h5
# Epoch 3/500
# 630/630 [==============================] - 596s 946ms/step - loss: 0.2417 - dice_cost_0: 0.7583 - val_loss: 0.2620 - val_dice_cost_0: 0.7375
#
# Epoch 00003: val_loss improved from 0.29093 to 0.26204, saving model to ./3D_dense_Unet_CV1.h5
# Epoch 4/500
# 630/630 [==============================] - 596s 946ms/step - loss: 0.2362 - dice_cost_0: 0.7638 - val_loss: 0.2580 - val_dice_cost_0: 0.7414
#
# Epoch 00004: val_loss improved from 0.26204 to 0.25798, saving model to ./3D_dense_Unet_CV1.h5
# Epoch 5/500
# 630/630 [==============================] - 597s 947ms/step - loss: 0.2240 - dice_cost_0: 0.7760 - val_loss: 0.2511 - val_dice_cost_0: 0.7480
#
# Epoch 00005: val_loss improved from 0.25798 to 0.25108, saving model to ./3D_dense_Unet_CV1.h5
# Epoch 6/500
# 630/630 [==============================] - 597s 947ms/step - loss: 0.2056 - dice_cost_0: 0.7944 - val_loss: 0.2692 - val_dice_cost_0: 0.7305
#
# Epoch 00006: val_loss did not improve from 0.25108
# Epoch 7/500
# 630/630 [==============================] - 597s 947ms/step - loss: 0.2065 - dice_cost_0: 0.7935 - val_loss: 0.2569 - val_dice_cost_0: 0.7424
#
# Epoch 00007: val_loss did not improve from 0.25108
# Epoch 8/500
# 630/630 [==============================] - 597s 947ms/step - loss: 0.2030 - dice_cost_0: 0.7970 - val_loss: 0.2512 - val_dice_cost_0: 0.7484
#
# Epoch 00008: val_loss did not improve from 0.25108
# Epoch 9/500
# 630/630 [==============================] - 597s 948ms/step - loss: 0.1908 - dice_cost_0: 0.8092 - val_loss: 0.2486 - val_dice_cost_0: 0.7509
#
# Epoch 00009: val_loss improved from 0.25108 to 0.24862, saving model to ./3D_dense_Unet_CV1.h5
# Epoch 10/500
# 630/630 [==============================] - 597s 947ms/step - loss: 0.1853 - dice_cost_0: 0.8147 - val_loss: 0.2518 - val_dice_cost_0: 0.7479
#
# Epoch 00010: val_loss did not improve from 0.24862
# Epoch 11/500
# 630/630 [==============================] - 597s 947ms/step - loss: 0.1808 - dice_cost_0: 0.8192 - val_loss: 0.2925 - val_dice_cost_0: 0.7070
#
# Epoch 00011: val_loss did not improve from 0.24862
# Epoch 12/500
# 630/630 [==============================] - 597s 947ms/step - loss: 0.1807 - dice_cost_0: 0.8193 - val_loss: 0.2413 - val_dice_cost_0: 0.7585
#
# Epoch 00012: val_loss improved from 0.24862 to 0.24130, saving model to ./3D_dense_Unet_CV1.h5
# Epoch 13/500
# 630/630 [==============================] - 597s 947ms/step - loss: 0.1683 - dice_cost_0: 0.8317 - val_loss: 0.2347 - val_dice_cost_0: 0.7648
#
# Epoch 00013: val_loss improved from 0.24130 to 0.23474, saving model to ./3D_dense_Unet_CV1.h5
# Epoch 14/500
# 630/630 [==============================] - 597s 947ms/step - loss: 0.1595 - dice_cost_0: 0.8405 - val_loss: 0.2324 - val_dice_cost_0: 0.7671
#
# Epoch 00014: val_loss improved from 0.23474 to 0.23236, saving model to ./3D_dense_Unet_CV1.h5
# Epoch 15/500
# 630/630 [==============================] - 597s 947ms/step - loss: 0.1609 - dice_cost_0: 0.8391 - val_loss: 0.2365 - val_dice_cost_0: 0.7631
#
# Epoch 00015: val_loss did not improve from 0.23236
# Epoch 16/500
# 630/630 [==============================] - 597s 947ms/step - loss: 0.1515 - dice_cost_0: 0.8485 - val_loss: 0.2449 - val_dice_cost_0: 0.7546
#
# Epoch 00016: val_loss did not improve from 0.23236
# Epoch 17/500
# 630/630 [==============================] - 597s 947ms/step - loss: 0.1426 - dice_cost_0: 0.8574 - val_loss: 0.2258 - val_dice_cost_0: 0.7738
#
# Epoch 00017: val_loss improved from 0.23236 to 0.22577, saving model to ./3D_dense_Unet_CV1.h5
# Epoch 18/500
# 630/630 [==============================] - 597s 947ms/step - loss: 0.1349 - dice_cost_0: 0.8651 - val_loss: 0.2320 - val_dice_cost_0: 0.7677
#
# Epoch 00018: val_loss did not improve from 0.22577
# Epoch 19/500
# 630/630 [==============================] - 597s 947ms/step - loss: 0.1306 - dice_cost_0: 0.8694 - val_loss: 0.2435 - val_dice_cost_0: 0.7562
#
# Epoch 00019: val_loss did not improve from 0.22577
# Epoch 20/500
# 630/630 [==============================] - 597s 947ms/step - loss: 0.1238 - dice_cost_0: 0.8762 - val_loss: 0.2318 - val_dice_cost_0: 0.7676
#
# Epoch 00020: val_loss did not improve from 0.22577
# Epoch 21/500
# 630/630 [==============================] - 597s 947ms/step - loss: 0.1186 - dice_cost_0: 0.8814 - val_loss: 0.2333 - val_dice_cost_0: 0.7663
#
# Epoch 00021: val_loss did not improve from 0.22577
# Epoch 22/500
# 630/630 [==============================] - 597s 948ms/step - loss: 0.1138 - dice_cost_0: 0.8862 - val_loss: 0.2428 - val_dice_cost_0: 0.7567
#
# Epoch 00022: val_loss did not improve from 0.22577
# Epoch 23/500
# 630/630 [==============================] - 597s 947ms/step - loss: 0.1123 - dice_cost_0: 0.8877 - val_loss: 0.2220 - val_dice_cost_0: 0.7774
#
# Epoch 00023: val_loss improved from 0.22577 to 0.22202, saving model to ./3D_dense_Unet_CV1.h5
# Epoch 24/500
# 630/630 [==============================] - 597s 947ms/step - loss: 0.1081 - dice_cost_0: 0.8919 - val_loss: 0.2342 - val_dice_cost_0: 0.7655
#
# Epoch 00024: val_loss did not improve from 0.22202
# Epoch 25/500
# 630/630 [==============================] - 596s 947ms/step - loss: 0.1018 - dice_cost_0: 0.8982 - val_loss: 0.2273 - val_dice_cost_0: 0.7721
#
# Epoch 00025: val_loss did not improve from 0.22202
# Epoch 26/500
# 630/630 [==============================] - 597s 947ms/step - loss: 0.0975 - dice_cost_0: 0.9025 - val_loss: 0.2223 - val_dice_cost_0: 0.7773
#
# Epoch 00026: val_loss did not improve from 0.22202
# Epoch 27/500
# 630/630 [==============================] - 596s 947ms/step - loss: 0.0938 - dice_cost_0: 0.9062 - val_loss: 0.2213 - val_dice_cost_0: 0.7779
#
# Epoch 00027: val_loss improved from 0.22202 to 0.22132, saving model to ./3D_dense_Unet_CV1.h5
# Epoch 28/500
# 630/630 [==============================] - 596s 947ms/step - loss: 0.0907 - dice_cost_0: 0.9093 - val_loss: 0.2254 - val_dice_cost_0: 0.7741
#
# Epoch 00028: val_loss did not improve from 0.22132
# Epoch 29/500
# 630/630 [==============================] - 596s 947ms/step - loss: 0.0888 - dice_cost_0: 0.9112 - val_loss: 0.2250 - val_dice_cost_0: 0.7746
#
# Epoch 00029: val_loss did not improve from 0.22132
# Epoch 30/500
# 630/630 [==============================] - 596s 947ms/step - loss: 0.0861 - dice_cost_0: 0.9139 - val_loss: 0.2235 - val_dice_cost_0: 0.7759
#
# Epoch 00030: val_loss did not improve from 0.22132
# Epoch 31/500
# 630/630 [==============================] - 597s 947ms/step - loss: 0.0827 - dice_cost_0: 0.9173 - val_loss: 0.2294 - val_dice_cost_0: 0.7702
#
# Epoch 00031: val_loss did not improve from 0.22132
# Epoch 32/500
# 630/630 [==============================] - 597s 947ms/step - loss: 0.0802 - dice_cost_0: 0.9198 - val_loss: 0.2205 - val_dice_cost_0: 0.7789
#
# Epoch 00032: val_loss improved from 0.22132 to 0.22048, saving model to ./3D_dense_Unet_CV1.h5
# Epoch 33/500
# 630/630 [==============================] - 596s 947ms/step - loss: 0.0782 - dice_cost_0: 0.9218 - val_loss: 0.2201 - val_dice_cost_0: 0.7792
#
# Epoch 00033: val_loss improved from 0.22048 to 0.22008, saving model to ./3D_dense_Unet_CV1.h5
# Epoch 34/500
# 630/630 [==============================] - 596s 946ms/step - loss: 0.0757 - dice_cost_0: 0.9243 - val_loss: 0.2225 - val_dice_cost_0: 0.7769
#
# Epoch 00034: val_loss did not improve from 0.22008
# Epoch 35/500
# 630/630 [==============================] - 597s 947ms/step - loss: 0.0726 - dice_cost_0: 0.9274 - val_loss: 0.2218 - val_dice_cost_0: 0.7776
#
# Epoch 00035: val_loss did not improve from 0.22008
# Epoch 36/500
# 630/630 [==============================] - 596s 947ms/step - loss: 0.0717 - dice_cost_0: 0.9283 - val_loss: 0.2308 - val_dice_cost_0: 0.7688
#
# Epoch 00036: val_loss did not improve from 0.22008
# Epoch 37/500
# 630/630 [==============================] - 597s 947ms/step - loss: 0.0818 - dice_cost_0: 0.9182 - val_loss: 0.2418 - val_dice_cost_0: 0.7579
#
# Epoch 00037: val_loss did not improve from 0.22008
# Epoch 38/500
# 630/630 [==============================] - 596s 947ms/step - loss: 0.0741 - dice_cost_0: 0.9259 - val_loss: 0.2236 - val_dice_cost_0: 0.7760
#
# Epoch 00038: val_loss did not improve from 0.22008
# Epoch 39/500
# 630/630 [==============================] - 597s 947ms/step - loss: 0.0667 - dice_cost_0: 0.9333 - val_loss: 0.2220 - val_dice_cost_0: 0.7775
#
# Epoch 00039: val_loss did not improve from 0.22008
# Epoch 40/500
# 630/630 [==============================] - 597s 947ms/step - loss: 0.0633 - dice_cost_0: 0.9367 - val_loss: 0.2195 - val_dice_cost_0: 0.7798
#
# Epoch 00040: val_loss improved from 0.22008 to 0.21950, saving model to ./3D_dense_Unet_CV1.h5
# Epoch 41/500
# 630/630 [==============================] - 597s 947ms/step - loss: 0.0629 - dice_cost_0: 0.9371 - val_loss: 0.2238 - val_dice_cost_0: 0.7758
#
# Epoch 00041: val_loss did not improve from 0.21950
# Epoch 42/500
# 630/630 [==============================] - 597s 947ms/step - loss: 0.0621 - dice_cost_0: 0.9379 - val_loss: 0.2189 - val_dice_cost_0: 0.7805
#
# Epoch 00042: val_loss improved from 0.21950 to 0.21888, saving model to ./3D_dense_Unet_CV1.h5
# Epoch 43/500
# 630/630 [==============================] - 596s 947ms/step - loss: 0.0606 - dice_cost_0: 0.9394 - val_loss: 0.2255 - val_dice_cost_0: 0.7741
#
# Epoch 00043: val_loss did not improve from 0.21888
# Epoch 44/500
# 630/630 [==============================] - 596s 947ms/step - loss: 0.0591 - dice_cost_0: 0.9409 - val_loss: 0.2200 - val_dice_cost_0: 0.7794
#
# Epoch 00044: val_loss did not improve from 0.21888
# Epoch 45/500
# 630/630 [==============================] - 597s 947ms/step - loss: 0.0598 - dice_cost_0: 0.9402 - val_loss: 0.2216 - val_dice_cost_0: 0.7778
#
# Epoch 00045: val_loss did not improve from 0.21888
# Epoch 46/500
# 630/630 [==============================] - 597s 947ms/step - loss: 0.0581 - dice_cost_0: 0.9419 - val_loss: 0.2214 - val_dice_cost_0: 0.7781
#
# Epoch 00046: val_loss did not improve from 0.21888
# Epoch 47/500
# 630/630 [==============================] - 596s 947ms/step - loss: 0.0560 - dice_cost_0: 0.9440 - val_loss: 0.2222 - val_dice_cost_0: 0.7773
#
# Epoch 00047: val_loss did not improve from 0.21888
# Epoch 48/500
# 630/630 [==============================] - 597s 947ms/step - loss: 0.0566 - dice_cost_0: 0.9434 - val_loss: 0.2261 - val_dice_cost_0: 0.7734
#
# Epoch 00048: val_loss did not improve from 0.21888
# Epoch 49/500
# 630/630 [==============================] - 597s 947ms/step - loss: 0.0560 - dice_cost_0: 0.9440 - val_loss: 0.2266 - val_dice_cost_0: 0.7728
#
# Epoch 00049: val_loss did not improve from 0.21888
# Epoch 50/500
# 630/630 [==============================] - 596s 947ms/step - loss: 0.0537 - dice_cost_0: 0.9463 - val_loss: 0.2204 - val_dice_cost_0: 0.7790
#
# Epoch 00050: val_loss did not improve from 0.21888
# Epoch 51/500
# 630/630 [==============================] - 596s 946ms/step - loss: 0.0519 - dice_cost_0: 0.9481 - val_loss: 0.2231 - val_dice_cost_0: 0.7763
#
# Epoch 00051: val_loss did not improve from 0.21888
# Epoch 52/500
# 630/630 [==============================] - 597s 947ms/step - loss: 0.0511 - dice_cost_0: 0.9489 - val_loss: 0.2246 - val_dice_cost_0: 0.7751
#
# Epoch 00052: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
#
# Epoch 00052: val_loss did not improve from 0.21888
# Epoch 53/500
# 630/630 [==============================] - 597s 947ms/step - loss: 0.0477 - dice_cost_0: 0.9523 - val_loss: 0.2148 - val_dice_cost_0: 0.7846
#
# Epoch 00053: val_loss improved from 0.21888 to 0.21481, saving model to ./3D_dense_Unet_CV1.h5
# Epoch 54/500
# 630/630 [==============================] - 596s 947ms/step - loss: 0.0448 - dice_cost_0: 0.9552 - val_loss: 0.2155 - val_dice_cost_0: 0.7840
#
# Epoch 00054: val_loss did not improve from 0.21481
# Epoch 55/500
# 630/630 [==============================] - 596s 947ms/step - loss: 0.0429 - dice_cost_0: 0.9571 - val_loss: 0.2158 - val_dice_cost_0: 0.7836
#
# Epoch 00055: val_loss did not improve from 0.21481
# Epoch 56/500
# 630/630 [==============================] - 596s 947ms/step - loss: 0.0417 - dice_cost_0: 0.9583 - val_loss: 0.2162 - val_dice_cost_0: 0.7832
#
# Epoch 00056: val_loss did not improve from 0.21481
# Epoch 57/500
# 630/630 [==============================] - 597s 947ms/step - loss: 0.0405 - dice_cost_0: 0.9595 - val_loss: 0.2165 - val_dice_cost_0: 0.7829
#
# Epoch 00057: val_loss did not improve from 0.21481
# Epoch 58/500
# 630/630 [==============================] - 597s 947ms/step - loss: 0.0394 - dice_cost_0: 0.9606 - val_loss: 0.2165 - val_dice_cost_0: 0.7829
#
# Epoch 00058: val_loss did not improve from 0.21481
# Epoch 59/500
# 630/630 [==============================] - 597s 947ms/step - loss: 0.0388 - dice_cost_0: 0.9612 - val_loss: 0.2170 - val_dice_cost_0: 0.7824
#
# Epoch 00059: val_loss did not improve from 0.21481
# Epoch 60/500
# 630/630 [==============================] - 597s 947ms/step - loss: 0.0380 - dice_cost_0: 0.9620 - val_loss: 0.2173 - val_dice_cost_0: 0.7821
#
# Epoch 00060: val_loss did not improve from 0.21481
# Epoch 61/500
# 630/630 [==============================] - 597s 947ms/step - loss: 0.0372 - dice_cost_0: 0.9628 - val_loss: 0.2167 - val_dice_cost_0: 0.7827
#
# Epoch 00061: val_loss did not improve from 0.21481
# Epoch 62/500
# 630/630 [==============================] - 596s 947ms/step - loss: 0.0369 - dice_cost_0: 0.9631 - val_loss: 0.2179 - val_dice_cost_0: 0.7815
#
# Epoch 00062: val_loss did not improve from 0.21481
# Epoch 63/500
# 630/630 [==============================] - 597s 947ms/step - loss: 0.0362 - dice_cost_0: 0.9638 - val_loss: 0.2175 - val_dice_cost_0: 0.7819
#
# Epoch 00063: ReduceLROnPlateau reducing learning rate to 1e-06.
#
# Epoch 00063: val_loss did not improve from 0.21481
# Epoch 64/500
# 630/630 [==============================] - 596s 947ms/step - loss: 0.0359 - dice_cost_0: 0.9641 - val_loss: 0.2179 - val_dice_cost_0: 0.7815
#
# Epoch 00064: val_loss did not improve from 0.21481
# Epoch 65/500
# 630/630 [==============================] - 596s 947ms/step - loss: 0.0354 - dice_cost_0: 0.9646 - val_loss: 0.2180 - val_dice_cost_0: 0.7815
#
# Epoch 00065: val_loss did not improve from 0.21481
# Epoch 66/500
# 630/630 [==============================] - 597s 947ms/step - loss: 0.0352 - dice_cost_0: 0.9648 - val_loss: 0.2180 - val_dice_cost_0: 0.7815
#
# Epoch 00066: val_loss did not improve from 0.21481
# Epoch 67/500
# 630/630 [==============================] - 597s 947ms/step - loss: 0.0353 - dice_cost_0: 0.9647 - val_loss: 0.2179 - val_dice_cost_0: 0.7816
#
# Epoch 00067: val_loss did not improve from 0.21481
# Epoch 68/500
# 630/630 [==============================] - 596s 947ms/step - loss: 0.0352 - dice_cost_0: 0.9648 - val_loss: 0.2178 - val_dice_cost_0: 0.7816
#
# Epoch 00068: val_loss did not improve from 0.21481
# Epoch 69/500
# 630/630 [==============================] - 597s 947ms/step - loss: 0.0352 - dice_cost_0: 0.9648 - val_loss: 0.2180 - val_dice_cost_0: 0.7815
#
# Epoch 00069: val_loss did not improve from 0.21481
# Epoch 70/500
# 548/630 [=========================>....] - ETA: 1:11 - loss: 0.0347 - dice_cost_0: 0.9653

# %%
fig = plt.figure()
# plt.axes(facecolor='white')
plt.plot(results.history['loss'])
plt.plot(results.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.savefig('loss.png')

# %%
from keras.models import load_model

#test_model = load_model('./3D_basic_Unet_CV1.h5',
#                   custom_objects = {'tversky_loss': tversky_loss,
#                                     'dice_cost_0': dice_cost_0,
#                                     'dice_cost_1': dice_cost_1,
#                                     'dice_cost_1_loss': dice_cost_1_loss})


test_model = load_model('./3D_dense_Unet_CV1.h5',
                   custom_objects = {'tversky_loss': tversky_loss,
                                     'dice_cost_0': dice_cost_0})

test_model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 128, 128, 128 0
# __________________________________________________________________________________________________
# conv3d_1 (Conv3D)               (None, 128, 128, 128 896         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 128, 128, 128 128         conv3d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 128, 128, 128 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv3d_2 (Conv3D)               (None, 128, 128, 128 27680       activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 128, 128, 128 128         conv3d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 128, 128, 128 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 128, 128, 128 0           activation_1[0][0]
#                                                                  activation_2[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_1 (MaxPooling3D)  (None, 64, 64, 64, 6 0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv3d_3 (Conv3D)               (None, 64, 64, 64, 6 110656      max_pooling3d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 64, 64, 64, 6 256         conv3d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 64, 64, 64, 6 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv3d_4 (Conv3D)               (None, 64, 64, 64, 6 110656      activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 64, 64, 64, 6 256         conv3d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 64, 64, 64, 6 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 64, 64, 64, 1 0           activation_3[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_2 (MaxPooling3D)  (None, 32, 32, 32, 1 0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv3d_5 (Conv3D)               (None, 32, 32, 32, 1 442496      max_pooling3d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 32, 32, 1 512         conv3d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 32, 32, 32, 1 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv3d_6 (Conv3D)               (None, 32, 32, 32, 1 442496      activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 32, 32, 32, 1 512         conv3d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 32, 32, 32, 1 0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 32, 32, 32, 2 0           activation_5[0][0]
#                                                                  activation_6[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_3 (MaxPooling3D)  (None, 16, 16, 16, 2 0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv3d_7 (Conv3D)               (None, 16, 16, 16, 2 1769728     max_pooling3d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 16, 16, 16, 2 1024        conv3d_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 16, 16, 16, 2 0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv3d_8 (Conv3D)               (None, 16, 16, 16, 2 1769728     activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 16, 16, 16, 2 1024        conv3d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 16, 16, 16, 2 0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 16, 16, 16, 5 0           activation_7[0][0]
#                                                                  activation_8[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_4 (MaxPooling3D)  (None, 8, 8, 8, 512) 0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv3d_9 (Conv3D)               (None, 8, 8, 8, 512) 7078400     max_pooling3d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 8, 8, 8, 512) 2048        conv3d_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 8, 8, 8, 512) 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv3d_10 (Conv3D)              (None, 8, 8, 8, 512) 7078400     activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 8, 8, 8, 512) 2048        conv3d_10[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 8, 8, 8, 512) 0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 8, 8, 8, 1024 0           activation_9[0][0]
#                                                                  activation_10[0][0]
# __________________________________________________________________________________________________
# up_sampling3d_1 (UpSampling3D)  (None, 16, 16, 16, 1 0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 16, 16, 16, 1 0           concatenate_4[0][0]
#                                                                  up_sampling3d_1[0][0]
# __________________________________________________________________________________________________
# conv3d_11 (Conv3D)              (None, 16, 16, 16, 2 10617088    concatenate_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 16, 16, 16, 2 1024        conv3d_11[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 16, 16, 16, 2 0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv3d_12 (Conv3D)              (None, 16, 16, 16, 2 1769728     activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 16, 16, 16, 2 1024        conv3d_12[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 16, 16, 16, 2 0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 16, 16, 16, 5 0           activation_11[0][0]
#                                                                  activation_12[0][0]
# __________________________________________________________________________________________________
# up_sampling3d_2 (UpSampling3D)  (None, 32, 32, 32, 5 0           concatenate_7[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 32, 32, 32, 7 0           concatenate_3[0][0]
#                                                                  up_sampling3d_2[0][0]
# __________________________________________________________________________________________________
# conv3d_13 (Conv3D)              (None, 32, 32, 32, 1 2654336     concatenate_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 32, 32, 32, 1 512         conv3d_13[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 32, 32, 32, 1 0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv3d_14 (Conv3D)              (None, 32, 32, 32, 1 442496      activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 32, 32, 32, 1 512         conv3d_14[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 32, 32, 32, 1 0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 32, 32, 32, 2 0           activation_13[0][0]
#                                                                  activation_14[0][0]
# __________________________________________________________________________________________________
# up_sampling3d_3 (UpSampling3D)  (None, 64, 64, 64, 2 0           concatenate_9[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 64, 64, 64, 3 0           concatenate_2[0][0]
#                                                                  up_sampling3d_3[0][0]
# __________________________________________________________________________________________________
# conv3d_15 (Conv3D)              (None, 64, 64, 64, 6 663616      concatenate_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 64, 64, 64, 6 256         conv3d_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 64, 64, 64, 6 0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv3d_16 (Conv3D)              (None, 64, 64, 64, 6 110656      activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 64, 64, 64, 6 256         conv3d_16[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 64, 64, 64, 6 0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 64, 64, 64, 1 0           activation_15[0][0]
#                                                                  activation_16[0][0]
# __________________________________________________________________________________________________
# up_sampling3d_4 (UpSampling3D)  (None, 128, 128, 128 0           concatenate_11[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 128, 128, 128 0           concatenate_1[0][0]
#                                                                  up_sampling3d_4[0][0]
# __________________________________________________________________________________________________
# conv3d_17 (Conv3D)              (None, 128, 128, 128 165920      concatenate_12[0][0]
# __________________________________________________________________________________________________
# conv3d_18 (Conv3D)              (None, 128, 128, 128 865         conv3d_17[0][0]
# ==================================================================================================
# Total params: 35,267,361
# Trainable params: 35,261,601
# Non-trainable params: 5,760
# __________________________________________________________________________________________________

# %%
test_img = np.load('./test_img.npy')
test_msk = np.load('./test_msk.npy')


test_img = test_img / 255.0

test_msk = test_msk[:,:,:,:,1]
test_msk = np.expand_dims(test_msk, axis=4)


print(test_img.shape, np.max(test_img), np.min(test_img), test_img.dtype)
print(test_msk.shape, np.max(test_msk), np.min(test_msk), test_msk.dtype)
# Out:
# (209, 128, 128, 128, 1) 1.0 0.0 float32
# (209, 128, 128, 128, 1) 1.0 0.0 float32

# %%
test_pred = test_model.predict(test_img, batch_size=2, verbose=1)
#test_pred = model.predict(test_img, batch_size=2, verbose=1)

np.save('./pred_result_CV1.npy', test_pred)

print(test_pred.shape, np.max(test_pred), np.min(test_pred), test_pred.dtype)
# Out:
# 209/209 [==============================] - 52s 247ms/step
# (209, 128, 128, 128, 1) 1.0 0.0 float32

# %%
# 평가지표 구하는 수식
recall_list = []
specificity_list = []
precision_list = []
acc_list = []
dice_list = []

for i in range(test_msk.shape[0]):
    for j in range(test_msk.shape[1]):
        
        seg1 = test_pred[i,j,:,:,0] > 0.5
        gt1 = test_msk[i,j,:,:,0]
        
        #if np.sum(gt1) != 0:
            
        seg1_n = seg1 == 0
        seg1_t = seg1 == 1
        
        gt1_n = gt1 == 0
        gt1_t = gt1 == 1
        
        tp = np.sum(seg1_t&gt1_t)
        
        fp = np.sum(seg1_t&gt1_n)
        
        tn = np.sum(seg1_n&gt1_n)
        
        fn = np.sum(seg1_n&gt1_t)
        
       
        recall = tp / (tp + fn)
        if np.isnan(recall):
            #print('recall is nan {0}\t(tp:{1})\t tn:{2}\t fp:{3}\t(fn:{4})'.format(i, tp, tn, fp, fn))
            continue
        
        specificity = tn / (tn + fp)
        if np.isnan(specificity):
            #print('specificity is nan {0}\t tp:{1}\t(tn:{2})\t(fp:{3})\t fn:{4}'.format(i, tp, tn, fp, fn))
            continue
        
        precision = tp / (tp + fp)
        if np.isnan(precision):
            #print('precision is nan {0}\t(tp:{1})\t tn:{2}\t(fp:{3})\t fn:{4}'.format(i, tp, tn, fp, fn))
            continue
        
        acc = (tp + tn) / (tp + tn + fp + fn)
        if np.isnan(acc):
            #print('acc is nan {0}\t(tp:{1})\t(tn:{2})\t(fp:{3})\t(fn:{4})'.format(i, tp, tn, fp, fn))
            continue
            
        dice = (2 * tp) / ((2 * tp) + fp + fn)
        if np.isnan(dice):
            #print('dice is nan {0}\t(tp:{1})\t tn:{2}\t(fp:{3})\t(fn:{4})'.format(i, tp, tn, fp, fn))
            continue
        
        #print('='*50)
        recall_list.append(recall)
        specificity_list.append(specificity)
        precision_list.append(precision)
        acc_list.append(acc)
        dice_list.append(dice)
# Out:
# /home/gil/anaconda3/envs/jjj/lib/python3.6/site-packages/ipykernel_launcher.py:31: RuntimeWarning: invalid value encountered in long_scalars
# /home/gil/anaconda3/envs/jjj/lib/python3.6/site-packages/ipykernel_launcher.py:41: RuntimeWarning: invalid value encountered in long_scalars

# %%
from tabulate import tabulate
row_data1 = []
row_item1 = []

    
row_item1.append('{0:.4f}'.format(np.mean(recall_list)))
row_item1.append('{0:.4f}'.format(np.mean(specificity_list)))
row_item1.append('{0:.4f}'.format(np.mean(precision_list)))
row_item1.append('{0:.4f}'.format(np.mean(acc_list)))
row_item1.append('{0:.4f}'.format(np.mean(dice_list)))
row_data1.append(row_item1)

head1 = ["Sensitivity", "Specificity", "Precision", "Accuracy", "DSC"]
  
# display table
print(tabulate(row_data1, headers=head1, tablefmt="grid"))
#print(row_data1[n])
print('')
# Out:
# +---------------+---------------+-------------+------------+--------+
# |   Sensitivity |   Specificity |   Precision |   Accuracy |    DSC |
# +===============+===============+=============+============+========+
# |        0.7585 |         0.991 |      0.7971 |      0.981 | 0.7469 |
# +---------------+---------------+-------------+------------+--------+

# %%
for i in range(0, test_img.shape[0]):
    
    os.makedirs('./result_img/' + str(format(i, '03')), exist_ok=True)
    for j in range(0, test_img.shape[1]):
        
        
        fig, axs = plt.subplots(1,3,constrained_layout=True)
        
        #plt.figure(figsize=(10, 20))
    
        axs[0].imshow(test_img[i,j,:,:,0], cmap='gray')
        axs[0].axis('off')
        

        axs[1].imshow(test_msk[i,j,:,:,0], cmap='gray')
        axs[1].axis('off')
    

        axs[2].imshow(test_img[i,j,:,:,0], cmap='gray')
        axs[2].imshow(test_pred[i,j,:,:,0] > 0.3, cmap='Reds', alpha=0.7)
        axs[2].axis('off')
    
        #plt.show()
        fig.savefig('./result_img/' + str(format(i, '03')) + '/'+ str(format(j, '03')) + '.png')
